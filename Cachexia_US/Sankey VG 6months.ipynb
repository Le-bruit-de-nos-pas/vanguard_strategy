# %%
import plotly.graph_objects as go
import pandas as pd
# Out:
# C:\Users\paulo\AppData\Local\Temp\ipykernel_22952\1086455191.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
fig = go.Figure(
    data = [go.Sankey(
        node = dict(
            pad = 15, 
            thickness = 20, 
            line = dict(color = "black", width = 0.5),
            color = "blue"
        ),
        link = dict(
            source = [0,0,1,1,2,2],
            target = [2,1,2,2,0,1],
            value = [1,1,1,2,1,1]
        )
    )]
)

# %%
fig.update_layout(title_text = "Sankey Diagram", font_size = 10)
fig.show()

# %%
df = pd.read_csv("temp_for_Sankey_HRPosHER2Neg_6m.csv")

# %%
df
# Out:
#           patient M_-6 M_-5 M_-4 M_-3 M_-2 M_-1 M_0 M_1 M_2 M_3 M_4 M_5 M_6
# 0     PT078274073   S8   S8   S8   S8   S8   S8  S8  S7  S7  S7  S7  S7  S7
# 1     PT078290563   S6   S6   S6   S6   S6   S6  S6  S6  S6  S6  S6  S6  S6
# 2     PT078387359   S6   S6   S6   S6   S6   S6  S6  S6  S6  S6  S6  S6  S6
# 3     PT078387372   S8   S8   S8   S8   S8   S8  S8  S8  S8  S8  S8  S8  S8
# 4     PT078392630   S7   S8   S8   S8   S7   S8  S8  S8  S8  S8  S8  S8  S8
# ...           ...  ...  ...  ...  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..
# 3664  PT744008776   S8   S7   S7   S7   S7   S7  S7  S8  S7  S7  S6  S6  S6
# 3665  PT744498854   S6   S6   S6   S6   S6   S6  S6  S6  S6  S6  S6  S6  S6
# 3666  PT752198070   S8   S8   S8   S8   S5   S5  S5  S5  S5  S5  S5  S5  S5
# 3667  PT753016269   S8   S8   S8   S8   S8   S8  S8  S8  S7  S7  S7  S7  S7
# 3668  PT753204085   S8   S8   S8   S8   S8   S8  S8  S8  S8  S8  S8  S8  S8
#
# [3669 rows x 14 columns]

# %%
groups = df.groupby(
    ['M_-6', 'M_-5', 'M_-4', 'M_-3', 'M_-2', 'M_-1', 'M_0', 'M_1', 'M_2', 'M_3', 'M_4', 'M_5', 'M_6' ]
     ).agg({'patient':'count'}).reset_index()

groups
# Out:
#     M_-6 M_-5 M_-4 M_-3 M_-2 M_-1 M_0 M_1 M_2 M_3 M_4 M_5 M_6  patient
# 0     S3   S3   S3   S3   S3   S3  S3  S3  S3  S3  S3  S3  S3        5
# 1     S3   S3   S3   S3   S3   S3  S3  S3  S3  S3  S4  S7  S3        1
# 2     S3   S3   S3   S3   S3   S3  S3  S3  S4  S4  S8  S8  S8        1
# 3     S3   S3   S3   S3   S3   S3  S3  S6  S6  S1  S1  S1  S1        1
# 4     S3   S3   S3   S3   S3   S3  S3  S7  S7  S7  S7  S7  S4        1
# ..   ...  ...  ...  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..      ...
# 992   S8   S8   S8   S8   S8   S8  S8  S8  S8  S8  S8  S8  S3        1
# 993   S8   S8   S8   S8   S8   S8  S8  S8  S8  S8  S8  S8  S5        2
# 994   S8   S8   S8   S8   S8   S8  S8  S8  S8  S8  S8  S8  S6        9
# 995   S8   S8   S8   S8   S8   S8  S8  S8  S8  S8  S8  S8  S7        8
# 996   S8   S8   S8   S8   S8   S8  S8  S8  S8  S8  S8  S8  S8      567
#
# [997 rows x 14 columns]

# %%
first_month =  groups.groupby(['M_-6', 'M_-5']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
second_month  =  groups.groupby(['M_-5', 'M_-4']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
third_month  =  groups.groupby(['M_-4', 'M_-3']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
fourth_month  =  groups.groupby(['M_-3', 'M_-2']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
fifth_month  =  groups.groupby(['M_-2', 'M_-1']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
sixth_month  =  groups.groupby(['M_-1', 'M_0']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
seventh_month  =  groups.groupby(['M_0', 'M_1']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
eighth_month  =  groups.groupby(['M_1', 'M_2']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
ninth_month  =  groups.groupby(['M_2', 'M_3']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
tenth_month  =  groups.groupby(['M_3', 'M_4']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
eleventh_month  =  groups.groupby(['M_4', 'M_5']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
twelfth_month  =  groups.groupby(['M_5', 'M_6']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()

# %%
list_=[first_month,second_month,third_month,fourth_month,fifth_month,sixth_month,seventh_month,eighth_month,ninth_month,tenth_month,eleventh_month,twelfth_month]
list_
# Out:
# [   M_-6 M_-5  patient
#  0    S3   S3       13
#  1    S3   S8        2
#  2    S4   S4       10
#  3    S4   S8        1
#  4    S5   S5       88
#  5    S5   S6        2
#  6    S6   S5        2
#  7    S6   S6      669
#  8    S6   S7        3
#  9    S6   S8       31
#  10   S7   S6       10
#  11   S7   S7       56
#  12   S7   S8       18
#  13   S8   S3        2
#  14   S8   S4        1
#  15   S8   S5        5
#  16   S8   S6       60
#  17   S8   S7       29
#  18   S8   S8     2667,
#     M_-5 M_-4  patient
#  0    S3   S3       15
#  1    S4   S4        9
#  2    S4   S6        1
#  3    S4   S8        1
#  4    S5   S5       89
#  5    S5   S6        4
#  6    S5   S8        2
#  7    S6   S4        1
#  8    S6   S5        2
#  9    S6   S6      702
#  10   S6   S7        5
#  11   S6   S8       31
#  12   S7   S6       12
#  13   S7   S7       67
#  14   S7   S8        9
#  15   S8   S4        2
#  16   S8   S5        5
#  17   S8   S6       51
#  18   S8   S7       35
#  19   S8   S8     2626,
#     M_-4 M_-3  patient
#  0    S3   S3       15
#  1    S4   S4       11
#  2    S4   S7        1
#  3    S5   S5       93
#  4    S5   S6        2
#  5    S5   S8        1
#  6    S6   S3        1
#  7    S6   S4        1
#  8    S6   S5        1
#  9    S6   S6      711
#  10   S6   S7        7
#  11   S6   S8       49
#  12   S7   S6       11
#  13   S7   S7       87
#  14   S7   S8        9
#  15   S8   S4        3
#  16   S8   S5        3
#  17   S8   S6       51
#  18   S8   S7       29
#  19   S8   S8     2583,
#     M_-3 M_-2  patient
#  0    S3   S3       14
#  1    S3   S5        1
#  2    S3   S7        1
#  3    S4   S4       12
#  4    S4   S6        2
#  5    S4   S8        1
#  6    S5   S5       90
#  7    S5   S6        1
#  8    S5   S8        6
#  9    S6   S3        1
#  10   S6   S5        3
#  11   S6   S6      726
#  12   S6   S7        4
#  13   S6   S8       41
#  14   S7   S6        8
#  15   S7   S7      101
#  16   S7   S8       15
#  17   S8   S4        1
#  18   S8   S5        3
#  19   S8   S6       47
#  20   S8   S7       29
#  21   S8   S8     2562,
#     M_-2 M_-1  patient
#  0    S3   S3       15
#  1    S4   S4       12
#  2    S4   S8        1
#  3    S5   S5       94
#  4    S5   S6        2
#  5    S5   S8        1
#  6    S6   S4        1
#  7    S6   S5        3
#  8    S6   S6      741
#  9    S6   S7        3
#  10   S6   S8       36
#  11   S7   S6        8
#  12   S7   S7      112
#  13   S7   S8       15
#  14   S8   S4        3
#  15   S8   S5        6
#  16   S8   S6       58
#  17   S8   S7       29
#  18   S8   S8     2529,
#     M_-1 M_0  patient
#  0    S3  S3       14
#  1    S3  S8        1
#  2    S4  S3        1
#  3    S4  S4       13
#  4    S4  S6        1
#  5    S4  S8        1
#  6    S5  S4        1
#  7    S5  S5       97
#  8    S5  S6        3
#  9    S5  S7        1
#  10   S5  S8        1
#  11   S6  S3        3
#  12   S6  S4        2
#  13   S6  S5        8
#  14   S6  S6      750
#  15   S6  S7        5
#  16   S6  S8       41
#  17   S7  S4        2
#  18   S7  S6       15
#  19   S7  S7       86
#  20   S7  S8       41
#  21   S8  S3        6
#  22   S8  S4       11
#  23   S8  S5        7
#  24   S8  S6      115
#  25   S8  S7       97
#  26   S8  S8     2346,
#     M_0 M_1  patient
#  0   S3  S3       20
#  1   S3  S6        1
#  2   S3  S7        2
#  3   S3  S8        1
#  4   S4  S3        4
#  5   S4  S4       22
#  6   S4  S6        2
#  7   S4  S8        1
#  8   S5  S3        2
#  9   S5  S4        3
#  10  S5  S5       99
#  11  S5  S6        3
#  12  S5  S8        5
#  13  S6  S3       16
#  14  S6  S4       20
#  15  S6  S5       13
#  16  S6  S6      754
#  17  S6  S7       22
#  18  S6  S8       59
#  19  S7  S4        5
#  20  S7  S5        6
#  21  S7  S6       24
#  22  S7  S7      111
#  23  S7  S8       43
#  24  S8  S3       24
#  25  S8  S4       55
#  26  S8  S5       23
#  27  S8  S6      239
#  28  S8  S7      380
#  29  S8  S8     1710,
#     M_1 M_2  patient
#  0   S3  S2        1
#  1   S3  S3       58
#  2   S3  S4        1
#  3   S3  S5        1
#  4   S3  S6        1
#  5   S3  S7        3
#  6   S3  S8        1
#  7   S4  S3        5
#  8   S4  S4       81
#  9   S4  S5        5
#  10  S4  S6        7
#  11  S4  S7        3
#  12  S4  S8        4
#  13  S5  S3        1
#  14  S5  S4        3
#  15  S5  S5      129
#  16  S5  S6        4
#  17  S5  S7        1
#  18  S5  S8        3
#  19  S6  S1        3
#  20  S6  S3       10
#  21  S6  S4       28
#  22  S6  S5       16
#  23  S6  S6      876
#  24  S6  S7       27
#  25  S6  S8       63
#  26  S7  S3        2
#  27  S7  S4        4
#  28  S7  S5        4
#  29  S7  S6       47
#  30  S7  S7      406
#  31  S7  S8       52
#  32  S8  S1       12
#  33  S8  S3        7
#  34  S8  S4       19
#  35  S8  S5       13
#  36  S8  S6      175
#  37  S8  S7      430
#  38  S8  S8     1163,
#     M_2 M_3  patient
#  0   S1  S1       15
#  1   S2  S6        1
#  2   S3  S1        1
#  3   S3  S3       74
#  4   S3  S4        3
#  5   S3  S5        2
#  6   S3  S7        2
#  7   S3  S8        1
#  8   S4  S3        4
#  9   S4  S4      112
#  10  S4  S5        3
#  11  S4  S6       12
#  12  S4  S7        1
#  13  S4  S8        4
#  14  S5  S1        4
#  15  S5  S3        2
#  16  S5  S4        2
#  17  S5  S5      149
#  18  S5  S6        7
#  19  S5  S7        1
#  20  S5  S8        3
#  21  S6  S1        3
#  22  S6  S3        2
#  23  S6  S4       14
#  24  S6  S5        9
#  25  S6  S6      979
#  26  S6  S7       37
#  27  S6  S8       66
#  28  S7  S1        1
#  29  S7  S3        3
#  30  S7  S4        3
#  31  S7  S5        6
#  32  S7  S6       84
#  33  S7  S7      726
#  34  S7  S8       47
#  35  S8  S1       30
#  36  S8  S3        5
#  37  S8  S4        3
#  38  S8  S5        5
#  39  S8  S6       84
#  40  S8  S7      170
#  41  S8  S8      989,
#     M_3 M_4  patient
#  0   S1  S1       54
#  1   S3  S3       84
#  2   S3  S4        2
#  3   S3  S6        2
#  4   S3  S8        2
#  5   S4  S1        1
#  6   S4  S3        2
#  7   S4  S4      123
#  8   S4  S5        4
#  9   S4  S6        2
#  10  S4  S7        1
#  11  S4  S8        4
#  12  S5  S1        1
#  13  S5  S3        1
#  14  S5  S4        6
#  15  S5  S5      158
#  16  S5  S6        3
#  17  S5  S7        2
#  18  S5  S8        3
#  19  S6  S1        4
#  20  S6  S3        1
#  21  S6  S4        5
#  22  S6  S5        6
#  23  S6  S6     1065
#  24  S6  S7       19
#  25  S6  S8       67
#  26  S7  S1        1
#  27  S7  S3        2
#  28  S7  S4        4
#  29  S7  S5        6
#  30  S7  S6       98
#  31  S7  S7      746
#  32  S7  S8       80
#  33  S8  S1       25
#  34  S8  S4        2
#  35  S8  S5        5
#  36  S8  S6       52
#  37  S8  S7       74
#  38  S8  S8      952,
#     M_4 M_5  patient
#  0   S1  S1       86
#  1   S3  S3       85
#  2   S3  S4        1
#  3   S3  S5        1
#  4   S3  S7        1
#  5   S3  S8        2
#  6   S4  S3        4
#  7   S4  S4      126
#  8   S4  S5        2
#  9   S4  S6        6
#  10  S4  S7        1
#  11  S4  S8        3
#  12  S5  S3        1
#  13  S5  S4        2
#  14  S5  S5      165
#  15  S5  S6        3
#  16  S5  S7        1
#  17  S5  S8        7
#  18  S6  S1        3
#  19  S6  S3        2
#  20  S6  S4       11
#  21  S6  S5       11
#  22  S6  S6     1130
#  23  S6  S7       11
#  24  S6  S8       54
#  25  S7  S1        2
#  26  S7  S3        2
#  27  S7  S4        1
#  28  S7  S5        5
#  29  S7  S6       84
#  30  S7  S7      655
#  31  S7  S8       93
#  32  S8  S1       19
#  33  S8  S3        1
#  34  S8  S5        2
#  35  S8  S6       54
#  36  S8  S7       36
#  37  S8  S8      996,
#     M_5 M_6  patient
#  0   S1  S1      110
#  1   S3  S3       91
#  2   S3  S4        1
#  3   S3  S7        1
#  4   S3  S8        2
#  5   S4  S3        3
#  6   S4  S4      120
#  7   S4  S5        5
#  8   S4  S6        9
#  9   S4  S7        2
#  10  S4  S8        2
#  11  S5  S3        2
#  12  S5  S4        3
#  13  S5  S5      167
#  14  S5  S6        8
#  15  S5  S8        6
#  16  S6  S1        1
#  17  S6  S3        6
#  18  S6  S5       10
#  19  S6  S6     1185
#  20  S6  S7        5
#  21  S6  S8       70
#  22  S7  S3        2
#  23  S7  S4        3
#  24  S7  S5        3
#  25  S7  S6       80
#  26  S7  S7      510
#  27  S7  S8      107
#  28  S8  S1       11
#  29  S8  S3        1
#  30  S8  S5        4
#  31  S8  S6       59
#  32  S8  S7       35
#  33  S8  S8     1045]

# %%
names = []
count_dict = {} #will contain all info of value list
source_list = [] #will contain all info of source
target_list = [] #will contain all info of target

# %%
for i in range(0, len(list_)):
    cols = list_[i].columns
    for x,y,z in zip(list_[i][cols[0]], list_[i][cols[1]], list_[i][cols[2]]):

        if(x+'_M'+str(i+1) not in names):
            names.append(x+'_M'+str(i+1))
        
        count_dict[x+'_M'+str(i+1), y+'_M'+str(i+2)] = z
        source_list.append(x+'_M'+str(i+1))
        target_list.append(y+'_M'+str(i+2))

# %%
source_list
target_list
names
count_dict
# Out:
# {('S3_M1', 'S3_M2'): 13,
#  ('S3_M1', 'S8_M2'): 2,
#  ('S4_M1', 'S4_M2'): 10,
#  ('S4_M1', 'S8_M2'): 1,
#  ('S5_M1', 'S5_M2'): 88,
#  ('S5_M1', 'S6_M2'): 2,
#  ('S6_M1', 'S5_M2'): 2,
#  ('S6_M1', 'S6_M2'): 669,
#  ('S6_M1', 'S7_M2'): 3,
#  ('S6_M1', 'S8_M2'): 31,
#  ('S7_M1', 'S6_M2'): 10,
#  ('S7_M1', 'S7_M2'): 56,
#  ('S7_M1', 'S8_M2'): 18,
#  ('S8_M1', 'S3_M2'): 2,
#  ('S8_M1', 'S4_M2'): 1,
#  ('S8_M1', 'S5_M2'): 5,
#  ('S8_M1', 'S6_M2'): 60,
#  ('S8_M1', 'S7_M2'): 29,
#  ('S8_M1', 'S8_M2'): 2667,
#  ('S3_M2', 'S3_M3'): 15,
#  ('S4_M2', 'S4_M3'): 9,
#  ('S4_M2', 'S6_M3'): 1,
#  ('S4_M2', 'S8_M3'): 1,
#  ('S5_M2', 'S5_M3'): 89,
#  ('S5_M2', 'S6_M3'): 4,
#  ('S5_M2', 'S8_M3'): 2,
#  ('S6_M2', 'S4_M3'): 1,
#  ('S6_M2', 'S5_M3'): 2,
#  ('S6_M2', 'S6_M3'): 702,
#  ('S6_M2', 'S7_M3'): 5,
#  ('S6_M2', 'S8_M3'): 31,
#  ('S7_M2', 'S6_M3'): 12,
#  ('S7_M2', 'S7_M3'): 67,
#  ('S7_M2', 'S8_M3'): 9,
#  ('S8_M2', 'S4_M3'): 2,
#  ('S8_M2', 'S5_M3'): 5,
#  ('S8_M2', 'S6_M3'): 51,
#  ('S8_M2', 'S7_M3'): 35,
#  ('S8_M2', 'S8_M3'): 2626,
#  ('S3_M3', 'S3_M4'): 15,
#  ('S4_M3', 'S4_M4'): 11,
#  ('S4_M3', 'S7_M4'): 1,
#  ('S5_M3', 'S5_M4'): 93,
#  ('S5_M3', 'S6_M4'): 2,
#  ('S5_M3', 'S8_M4'): 1,
#  ('S6_M3', 'S3_M4'): 1,
#  ('S6_M3', 'S4_M4'): 1,
#  ('S6_M3', 'S5_M4'): 1,
#  ('S6_M3', 'S6_M4'): 711,
#  ('S6_M3', 'S7_M4'): 7,
#  ('S6_M3', 'S8_M4'): 49,
#  ('S7_M3', 'S6_M4'): 11,
#  ('S7_M3', 'S7_M4'): 87,
#  ('S7_M3', 'S8_M4'): 9,
#  ('S8_M3', 'S4_M4'): 3,
#  ('S8_M3', 'S5_M4'): 3,
#  ('S8_M3', 'S6_M4'): 51,
#  ('S8_M3', 'S7_M4'): 29,
#  ('S8_M3', 'S8_M4'): 2583,
#  ('S3_M4', 'S3_M5'): 14,
#  ('S3_M4', 'S5_M5'): 1,
#  ('S3_M4', 'S7_M5'): 1,
#  ('S4_M4', 'S4_M5'): 12,
#  ('S4_M4', 'S6_M5'): 2,
#  ('S4_M4', 'S8_M5'): 1,
#  ('S5_M4', 'S5_M5'): 90,
#  ('S5_M4', 'S6_M5'): 1,
#  ('S5_M4', 'S8_M5'): 6,
#  ('S6_M4', 'S3_M5'): 1,
#  ('S6_M4', 'S5_M5'): 3,
#  ('S6_M4', 'S6_M5'): 726,
#  ('S6_M4', 'S7_M5'): 4,
#  ('S6_M4', 'S8_M5'): 41,
#  ('S7_M4', 'S6_M5'): 8,
#  ('S7_M4', 'S7_M5'): 101,
#  ('S7_M4', 'S8_M5'): 15,
#  ('S8_M4', 'S4_M5'): 1,
#  ('S8_M4', 'S5_M5'): 3,
#  ('S8_M4', 'S6_M5'): 47,
#  ('S8_M4', 'S7_M5'): 29,
#  ('S8_M4', 'S8_M5'): 2562,
#  ('S3_M5', 'S3_M6'): 15,
#  ('S4_M5', 'S4_M6'): 12,
#  ('S4_M5', 'S8_M6'): 1,
#  ('S5_M5', 'S5_M6'): 94,
#  ('S5_M5', 'S6_M6'): 2,
#  ('S5_M5', 'S8_M6'): 1,
#  ('S6_M5', 'S4_M6'): 1,
#  ('S6_M5', 'S5_M6'): 3,
#  ('S6_M5', 'S6_M6'): 741,
#  ('S6_M5', 'S7_M6'): 3,
#  ('S6_M5', 'S8_M6'): 36,
#  ('S7_M5', 'S6_M6'): 8,
#  ('S7_M5', 'S7_M6'): 112,
#  ('S7_M5', 'S8_M6'): 15,
#  ('S8_M5', 'S4_M6'): 3,
#  ('S8_M5', 'S5_M6'): 6,
#  ('S8_M5', 'S6_M6'): 58,
#  ('S8_M5', 'S7_M6'): 29,
#  ('S8_M5', 'S8_M6'): 2529,
#  ('S3_M6', 'S3_M7'): 14,
#  ('S3_M6', 'S8_M7'): 1,
#  ('S4_M6', 'S3_M7'): 1,
#  ('S4_M6', 'S4_M7'): 13,
#  ('S4_M6', 'S6_M7'): 1,
#  ('S4_M6', 'S8_M7'): 1,
#  ('S5_M6', 'S4_M7'): 1,
#  ('S5_M6', 'S5_M7'): 97,
#  ('S5_M6', 'S6_M7'): 3,
#  ('S5_M6', 'S7_M7'): 1,
#  ('S5_M6', 'S8_M7'): 1,
#  ('S6_M6', 'S3_M7'): 3,
#  ('S6_M6', 'S4_M7'): 2,
#  ('S6_M6', 'S5_M7'): 8,
#  ('S6_M6', 'S6_M7'): 750,
#  ('S6_M6', 'S7_M7'): 5,
#  ('S6_M6', 'S8_M7'): 41,
#  ('S7_M6', 'S4_M7'): 2,
#  ('S7_M6', 'S6_M7'): 15,
#  ('S7_M6', 'S7_M7'): 86,
#  ('S7_M6', 'S8_M7'): 41,
#  ('S8_M6', 'S3_M7'): 6,
#  ('S8_M6', 'S4_M7'): 11,
#  ('S8_M6', 'S5_M7'): 7,
#  ('S8_M6', 'S6_M7'): 115,
#  ('S8_M6', 'S7_M7'): 97,
#  ('S8_M6', 'S8_M7'): 2346,
#  ('S3_M7', 'S3_M8'): 20,
#  ('S3_M7', 'S6_M8'): 1,
#  ('S3_M7', 'S7_M8'): 2,
#  ('S3_M7', 'S8_M8'): 1,
#  ('S4_M7', 'S3_M8'): 4,
#  ('S4_M7', 'S4_M8'): 22,
#  ('S4_M7', 'S6_M8'): 2,
#  ('S4_M7', 'S8_M8'): 1,
#  ('S5_M7', 'S3_M8'): 2,
#  ('S5_M7', 'S4_M8'): 3,
#  ('S5_M7', 'S5_M8'): 99,
#  ('S5_M7', 'S6_M8'): 3,
#  ('S5_M7', 'S8_M8'): 5,
#  ('S6_M7', 'S3_M8'): 16,
#  ('S6_M7', 'S4_M8'): 20,
#  ('S6_M7', 'S5_M8'): 13,
#  ('S6_M7', 'S6_M8'): 754,
#  ('S6_M7', 'S7_M8'): 22,
#  ('S6_M7', 'S8_M8'): 59,
#  ('S7_M7', 'S4_M8'): 5,
#  ('S7_M7', 'S5_M8'): 6,
#  ('S7_M7', 'S6_M8'): 24,
#  ('S7_M7', 'S7_M8'): 111,
#  ('S7_M7', 'S8_M8'): 43,
#  ('S8_M7', 'S3_M8'): 24,
#  ('S8_M7', 'S4_M8'): 55,
#  ('S8_M7', 'S5_M8'): 23,
#  ('S8_M7', 'S6_M8'): 239,
#  ('S8_M7', 'S7_M8'): 380,
#  ('S8_M7', 'S8_M8'): 1710,
#  ('S3_M8', 'S2_M9'): 1,
#  ('S3_M8', 'S3_M9'): 58,
#  ('S3_M8', 'S4_M9'): 1,
#  ('S3_M8', 'S5_M9'): 1,
#  ('S3_M8', 'S6_M9'): 1,
#  ('S3_M8', 'S7_M9'): 3,
#  ('S3_M8', 'S8_M9'): 1,
#  ('S4_M8', 'S3_M9'): 5,
#  ('S4_M8', 'S4_M9'): 81,
#  ('S4_M8', 'S5_M9'): 5,
#  ('S4_M8', 'S6_M9'): 7,
#  ('S4_M8', 'S7_M9'): 3,
#  ('S4_M8', 'S8_M9'): 4,
#  ('S5_M8', 'S3_M9'): 1,
#  ('S5_M8', 'S4_M9'): 3,
#  ('S5_M8', 'S5_M9'): 129,
#  ('S5_M8', 'S6_M9'): 4,
#  ('S5_M8', 'S7_M9'): 1,
#  ('S5_M8', 'S8_M9'): 3,
#  ('S6_M8', 'S1_M9'): 3,
#  ('S6_M8', 'S3_M9'): 10,
#  ('S6_M8', 'S4_M9'): 28,
#  ('S6_M8', 'S5_M9'): 16,
#  ('S6_M8', 'S6_M9'): 876,
#  ('S6_M8', 'S7_M9'): 27,
#  ('S6_M8', 'S8_M9'): 63,
#  ('S7_M8', 'S3_M9'): 2,
#  ('S7_M8', 'S4_M9'): 4,
#  ('S7_M8', 'S5_M9'): 4,
#  ('S7_M8', 'S6_M9'): 47,
#  ('S7_M8', 'S7_M9'): 406,
#  ('S7_M8', 'S8_M9'): 52,
#  ('S8_M8', 'S1_M9'): 12,
#  ('S8_M8', 'S3_M9'): 7,
#  ('S8_M8', 'S4_M9'): 19,
#  ('S8_M8', 'S5_M9'): 13,
#  ('S8_M8', 'S6_M9'): 175,
#  ('S8_M8', 'S7_M9'): 430,
#  ('S8_M8', 'S8_M9'): 1163,
#  ('S1_M9', 'S1_M10'): 15,
#  ('S2_M9', 'S6_M10'): 1,
#  ('S3_M9', 'S1_M10'): 1,
#  ('S3_M9', 'S3_M10'): 74,
#  ('S3_M9', 'S4_M10'): 3,
#  ('S3_M9', 'S5_M10'): 2,
#  ('S3_M9', 'S7_M10'): 2,
#  ('S3_M9', 'S8_M10'): 1,
#  ('S4_M9', 'S3_M10'): 4,
#  ('S4_M9', 'S4_M10'): 112,
#  ('S4_M9', 'S5_M10'): 3,
#  ('S4_M9', 'S6_M10'): 12,
#  ('S4_M9', 'S7_M10'): 1,
#  ('S4_M9', 'S8_M10'): 4,
#  ('S5_M9', 'S1_M10'): 4,
#  ('S5_M9', 'S3_M10'): 2,
#  ('S5_M9', 'S4_M10'): 2,
#  ('S5_M9', 'S5_M10'): 149,
#  ('S5_M9', 'S6_M10'): 7,
#  ('S5_M9', 'S7_M10'): 1,
#  ('S5_M9', 'S8_M10'): 3,
#  ('S6_M9', 'S1_M10'): 3,
#  ('S6_M9', 'S3_M10'): 2,
#  ('S6_M9', 'S4_M10'): 14,
#  ('S6_M9', 'S5_M10'): 9,
#  ('S6_M9', 'S6_M10'): 979,
#  ('S6_M9', 'S7_M10'): 37,
#  ('S6_M9', 'S8_M10'): 66,
#  ('S7_M9', 'S1_M10'): 1,
#  ('S7_M9', 'S3_M10'): 3,
#  ('S7_M9', 'S4_M10'): 3,
#  ('S7_M9', 'S5_M10'): 6,
#  ('S7_M9', 'S6_M10'): 84,
#  ('S7_M9', 'S7_M10'): 726,
#  ('S7_M9', 'S8_M10'): 47,
#  ('S8_M9', 'S1_M10'): 30,
#  ('S8_M9', 'S3_M10'): 5,
#  ('S8_M9', 'S4_M10'): 3,
#  ('S8_M9', 'S5_M10'): 5,
#  ('S8_M9', 'S6_M10'): 84,
#  ('S8_M9', 'S7_M10'): 170,
#  ('S8_M9', 'S8_M10'): 989,
#  ('S1_M10', 'S1_M11'): 54,
#  ('S3_M10', 'S3_M11'): 84,
#  ('S3_M10', 'S4_M11'): 2,
#  ('S3_M10', 'S6_M11'): 2,
#  ('S3_M10', 'S8_M11'): 2,
#  ('S4_M10', 'S1_M11'): 1,
#  ('S4_M10', 'S3_M11'): 2,
#  ('S4_M10', 'S4_M11'): 123,
#  ('S4_M10', 'S5_M11'): 4,
#  ('S4_M10', 'S6_M11'): 2,
#  ('S4_M10', 'S7_M11'): 1,
#  ('S4_M10', 'S8_M11'): 4,
#  ('S5_M10', 'S1_M11'): 1,
#  ('S5_M10', 'S3_M11'): 1,
#  ('S5_M10', 'S4_M11'): 6,
#  ('S5_M10', 'S5_M11'): 158,
#  ('S5_M10', 'S6_M11'): 3,
#  ('S5_M10', 'S7_M11'): 2,
#  ('S5_M10', 'S8_M11'): 3,
#  ('S6_M10', 'S1_M11'): 4,
#  ('S6_M10', 'S3_M11'): 1,
#  ('S6_M10', 'S4_M11'): 5,
#  ('S6_M10', 'S5_M11'): 6,
#  ('S6_M10', 'S6_M11'): 1065,
#  ('S6_M10', 'S7_M11'): 19,
#  ('S6_M10', 'S8_M11'): 67,
#  ('S7_M10', 'S1_M11'): 1,
#  ('S7_M10', 'S3_M11'): 2,
#  ('S7_M10', 'S4_M11'): 4,
#  ('S7_M10', 'S5_M11'): 6,
#  ('S7_M10', 'S6_M11'): 98,
#  ('S7_M10', 'S7_M11'): 746,
#  ('S7_M10', 'S8_M11'): 80,
#  ('S8_M10', 'S1_M11'): 25,
#  ('S8_M10', 'S4_M11'): 2,
#  ('S8_M10', 'S5_M11'): 5,
#  ('S8_M10', 'S6_M11'): 52,
#  ('S8_M10', 'S7_M11'): 74,
#  ('S8_M10', 'S8_M11'): 952,
#  ('S1_M11', 'S1_M12'): 86,
#  ('S3_M11', 'S3_M12'): 85,
#  ('S3_M11', 'S4_M12'): 1,
#  ('S3_M11', 'S5_M12'): 1,
#  ('S3_M11', 'S7_M12'): 1,
#  ('S3_M11', 'S8_M12'): 2,
#  ('S4_M11', 'S3_M12'): 4,
#  ('S4_M11', 'S4_M12'): 126,
#  ('S4_M11', 'S5_M12'): 2,
#  ('S4_M11', 'S6_M12'): 6,
#  ('S4_M11', 'S7_M12'): 1,
#  ('S4_M11', 'S8_M12'): 3,
#  ('S5_M11', 'S3_M12'): 1,
#  ('S5_M11', 'S4_M12'): 2,
#  ('S5_M11', 'S5_M12'): 165,
#  ('S5_M11', 'S6_M12'): 3,
#  ('S5_M11', 'S7_M12'): 1,
#  ('S5_M11', 'S8_M12'): 7,
#  ('S6_M11', 'S1_M12'): 3,
#  ('S6_M11', 'S3_M12'): 2,
#  ('S6_M11', 'S4_M12'): 11,
#  ('S6_M11', 'S5_M12'): 11,
#  ('S6_M11', 'S6_M12'): 1130,
#  ('S6_M11', 'S7_M12'): 11,
#  ('S6_M11', 'S8_M12'): 54,
#  ('S7_M11', 'S1_M12'): 2,
#  ('S7_M11', 'S3_M12'): 2,
#  ('S7_M11', 'S4_M12'): 1,
#  ('S7_M11', 'S5_M12'): 5,
#  ('S7_M11', 'S6_M12'): 84,
#  ('S7_M11', 'S7_M12'): 655,
#  ('S7_M11', 'S8_M12'): 93,
#  ('S8_M11', 'S1_M12'): 19,
#  ('S8_M11', 'S3_M12'): 1,
#  ('S8_M11', 'S5_M12'): 2,
#  ('S8_M11', 'S6_M12'): 54,
#  ('S8_M11', 'S7_M12'): 36,
#  ('S8_M11', 'S8_M12'): 996,
#  ('S1_M12', 'S1_M13'): 110,
#  ('S3_M12', 'S3_M13'): 91,
#  ('S3_M12', 'S4_M13'): 1,
#  ('S3_M12', 'S7_M13'): 1,
#  ('S3_M12', 'S8_M13'): 2,
#  ('S4_M12', 'S3_M13'): 3,
#  ('S4_M12', 'S4_M13'): 120,
#  ('S4_M12', 'S5_M13'): 5,
#  ('S4_M12', 'S6_M13'): 9,
#  ('S4_M12', 'S7_M13'): 2,
#  ('S4_M12', 'S8_M13'): 2,
#  ('S5_M12', 'S3_M13'): 2,
#  ('S5_M12', 'S4_M13'): 3,
#  ('S5_M12', 'S5_M13'): 167,
#  ('S5_M12', 'S6_M13'): 8,
#  ('S5_M12', 'S8_M13'): 6,
#  ('S6_M12', 'S1_M13'): 1,
#  ('S6_M12', 'S3_M13'): 6,
#  ('S6_M12', 'S5_M13'): 10,
#  ('S6_M12', 'S6_M13'): 1185,
#  ('S6_M12', 'S7_M13'): 5,
#  ('S6_M12', 'S8_M13'): 70,
#  ('S7_M12', 'S3_M13'): 2,
#  ('S7_M12', 'S4_M13'): 3,
#  ('S7_M12', 'S5_M13'): 3,
#  ('S7_M12', 'S6_M13'): 80,
#  ('S7_M12', 'S7_M13'): 510,
#  ('S7_M12', 'S8_M13'): 107,
#  ('S8_M12', 'S1_M13'): 11,
#  ('S8_M12', 'S3_M13'): 1,
#  ('S8_M12', 'S5_M13'): 4,
#  ('S8_M12', 'S6_M13'): 59,
#  ('S8_M12', 'S7_M13'): 35,
#  ('S8_M12', 'S8_M13'): 1045}

# %%
for v in target_list:
    if v not in names:
        names.append(v)

# %%
all_numerics = {}

for i in range(0, len(names)):
    all_numerics[names[i]] = i

# %%
fig = go.Figure(data = [go.Sankey(
    node=dict(thickness=5, color='blue',),
    link=dict(
        source = [all_numerics[x] for x in source_list],
        target = [all_numerics[x] for x in target_list],
        value = [count_dict[x,y] for x,y in zip(source_list,target_list)],
    )
)])

# %%
fig.update_layout(font_size=15, width=1200, height=800, margin=dict(t=30,l=30,b=30,r=30))
fig.show()

# %%
names
# Out:
# ['S3_M1',
#  'S4_M1',
#  'S5_M1',
#  'S6_M1',
#  'S7_M1',
#  'S8_M1',
#  'S3_M2',
#  'S4_M2',
#  'S5_M2',
#  'S6_M2',
#  'S7_M2',
#  'S8_M2',
#  'S3_M3',
#  'S4_M3',
#  'S5_M3',
#  'S6_M3',
#  'S7_M3',
#  'S8_M3',
#  'S3_M4',
#  'S4_M4',
#  'S5_M4',
#  'S6_M4',
#  'S7_M4',
#  'S8_M4',
#  'S3_M5',
#  'S4_M5',
#  'S5_M5',
#  'S6_M5',
#  'S7_M5',
#  'S8_M5',
#  'S3_M6',
#  'S4_M6',
#  'S5_M6',
#  'S6_M6',
#  'S7_M6',
#  'S8_M6',
#  'S3_M7',
#  'S4_M7',
#  'S5_M7',
#  'S6_M7',
#  'S7_M7',
#  'S8_M7',
#  'S3_M8',
#  'S4_M8',
#  'S5_M8',
#  'S6_M8',
#  'S7_M8',
#  'S8_M8',
#  'S1_M9',
#  'S2_M9',
#  'S3_M9',
#  'S4_M9',
#  'S5_M9',
#  'S6_M9',
#  'S7_M9',
#  'S8_M9',
#  'S1_M10',
#  'S3_M10',
#  'S4_M10',
#  'S5_M10',
#  'S6_M10',
#  'S7_M10',
#  'S8_M10',
#  'S1_M11',
#  'S3_M11',
#  'S4_M11',
#  'S5_M11',
#  'S6_M11',
#  'S7_M11',
#  'S8_M11',
#  'S1_M12',
#  'S3_M12',
#  'S4_M12',
#  'S5_M12',
#  'S6_M12',
#  'S7_M12',
#  'S8_M12',
#  'S1_M13',
#  'S3_M13',
#  'S4_M13',
#  'S7_M13',
#  'S8_M13',
#  'S5_M13',
#  'S6_M13']

# %%
color_dict = {
    'S1': 'rgba(255, 87, 34, 0.7)',   # Orange
    'S2': 'rgba(0, 0, 0, 0.7)',   # Black
    'S3': 'rgba(156, 39, 176, 0.7)',   # Purple
    'S4': 'rgba(76, 175, 80, 0.7)',   # Green
    'S5': 'rgba(255, 193, 7, 0.7)',   # Amber
    'S6': 'rgba(33, 150, 243, 0.7)',   # Indigo
    'S7': 'rgba(233, 30, 99, 0.7)',   # Pink
    'S8': 'rgba(255, 152, 0, 0.7)'   # Deep Orange
}


color_dict_link = {
    'S1': 'rgba(255, 87, 34, 0.3)',   # Orange
    'S2': 'rgba(0, 0, 0, 0.7)',   # Black
    'S3': 'rgba(156, 39, 176, 0.3)',   # Purple
    'S4': 'rgba(76, 175, 80, 0.3)',   # Green
    'S5': 'rgba(255, 193, 7, 0.3)',   # Amber
    'S6': 'rgba(33, 150, 243, 0.3)',   # Indigo
    'S7': 'rgba(233, 30, 99, 0.3)',   # Pink
    'S8': 'rgba(255, 152, 0, 0.3)'   # Deep Orange
}

# %%
color_dict = {
    'S1': 'rgba(244, 238, 225, 0.7)',   # Light Beige
    'S2': 'rgba(244, 238, 225, 0.7)',   # Light Beige
    'S3': 'rgba(255, 105, 180, 1.0)',   # Strong Pink Redish
    'S4': 'rgba(65, 105, 225, 1.0)',   # Strong Attractive Blue
    'S5': 'rgba(244, 238, 225, 0.7)',   # Light Beige
    'S6': 'rgba(244, 238, 225, 0.7)',   # Light Beige
    'S7': 'rgba(244, 238, 225, 0.7)',   # Light Beige
    'S8': 'rgba(192, 192, 192, 0.7)'   # Lighter Gray
}

color_dict_link = {
    'S1': 'rgba(244, 238, 225, 0.3)',   # Light Beige
    'S2': 'rgba(244, 238, 225, 0.3)',   # Light Beige
    'S3': 'rgba(255, 105, 180, 0.7)',   # Strong Pink Redish
    'S4': 'rgba(65, 105, 225, 0.7)',   # Strong Attractive Blue
    'S5': 'rgba(244, 238, 225, 0.3)',   # Light Beige
    'S6': 'rgba(244, 238, 225, 0.3)',   # Light Beige
    'S7': 'rgba(244, 238, 225, 0.3)',   # Light Beige
    'S8': 'rgba(192, 192, 192, 0.3)'   # Lighter Gray
}

# %%
fig = go.Figure(data = [go.Sankey(
    node=dict(
        thickness=10,
         line = dict(color = None, width = 0.01),
         color= [color_dict[x.split('_')[0]] for x in names],),
    link=dict(
        source = [all_numerics[x] for x in source_list],
        target = [all_numerics[x] for x in target_list],
        value = [count_dict[x,y] for x,y in zip(source_list,target_list)],
        color= [color_dict_link[x.split('_')[0]] for x in target_list]
    )
)])

# %%
fig.update_layout(font_size=15, width=1200, height=800, margin=dict(t=30,l=30,b=30,r=30))
