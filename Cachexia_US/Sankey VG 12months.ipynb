# %%
import plotly.graph_objects as go
import pandas as pd
# Out:
# C:\Users\paulo\AppData\Local\Temp\ipykernel_5360\1086455191.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
fig = go.Figure(
    data = [go.Sankey(
        node = dict(
            pad = 15, 
            thickness = 20, 
            line = dict(color = "black", width = 0.5),
            color = "blue"
        ),
        link = dict(
            source = [0,0,1,1,2,2],
            target = [2,1,2,2,0,1],
            value = [1,1,1,2,1,1]
        )
    )]
)

# %%
fig.update_layout(title_text = "Sankey Diagram", font_size = 10)
fig.show()

# %%
# df = pd.read_csv("temp_for_Sankey_HRPosHER2Neg_12m.csv")
# df = pd.read_csv("temp_for_Sankey_HRNegHER2Pos_12m.csv")
# df = pd.read_csv("temp_for_Sankey_HRNegHER2Neg_12m.csv")
df = pd.read_csv("temp_for_Sankey_HRPosHER2Pos_12m.csv")

# %%
df
# Out:
#           patient M_-12 M_-11 M_-10 M_-9 M_-8 M_-7 M_-6 M_-5 M_-4  ... M_3  \
# 0     PT078330324    S8    S8    S8   S8   S8   S8   S8   S8   S8  ...  S5
# 1     PT080993475    S8    S8    S8   S8   S8   S8   S8   S8   S8  ...  S8
# 2     PT081425734    S8    S8    S8   S8   S8   S8   S8   S5   S5  ...  S5
# 3     PT081728820    S8    S8    S8   S8   S8   S8   S8   S8   S8  ...  S5
# 4     PT082121765    S8    S8    S8   S8   S8   S8   S8   S8   S8  ...  S7
# ...           ...   ...   ...   ...  ...  ...  ...  ...  ...  ...  ...  ..
# 1093  PT735382536    S8    S8    S8   S8   S8   S8   S8   S8   S8  ...  S5
# 1094  PT735463391    S8    S8    S8   S8   S8   S8   S8   S8   S8  ...  S7
# 1095  PT735687837    S8    S8    S8   S8   S8   S8   S8   S8   S8  ...  S7
# 1096  PT735711955    S8    S8    S8   S8   S8   S8   S8   S8   S8  ...  S6
# 1097  PT755053006    S8    S8    S8   S8   S8   S8   S8   S8   S5  ...  S5
#
#      M_4 M_5 M_6 M_7 M_8 M_9 M_10 M_11 M_12
# 0     S5  S5  S5  S5  S5  S5   S3   S3   S3
# 1     S8  S8  S8  S8  S8  S8   S8   S8   S8
# 2     S5  S5  S5  S5  S8  S8   S8   S8   S8
# 3     S5  S5  S5  S5  S6  S6   S6   S6   S6
# 4     S6  S6  S6  S6  S6  S8   S8   S8   S8
# ...   ..  ..  ..  ..  ..  ..  ...  ...  ...
# 1093  S5  S5  S5  S5  S5  S5   S5   S5   S5
# 1094  S5  S5  S5  S5  S5  S5   S5   S5   S5
# 1095  S7  S7  S5  S5  S5  S5   S5   S5   S5
# 1096  S6  S6  S6  S6  S6  S6   S6   S6   S6
# 1097  S5  S5  S5  S5  S5  S5   S5   S6   S6
#
# [1098 rows x 26 columns]

# %%
groups = df.groupby(
    ['M_-12','M_-11','M_-10','M_-9','M_-8','M_-7','M_-6', 'M_-5', 'M_-4', 'M_-3', 'M_-2', 'M_-1', 'M_0', 
     'M_1', 'M_2', 'M_3', 'M_4', 'M_5', 'M_6', 'M_7', 'M_8', 'M_9', 'M_10', 'M_11', 'M_12' ]
     ).agg({'patient':'count'}).reset_index()

groups
# Out:
#     M_-12 M_-11 M_-10 M_-9 M_-8 M_-7 M_-6 M_-5 M_-4 M_-3  ... M_4 M_5 M_6 M_7  \
# 0      S3    S3    S3   S3   S3   S3   S3   S3   S3   S3  ...  S3  S3  S3  S3
# 1      S3    S3    S3   S3   S3   S3   S3   S3   S3   S3  ...  S8  S1  S1  S1
# 2      S4    S5    S5   S5   S4   S5   S5   S5   S5   S5  ...  S3  S3  S3  S5
# 3      S5    S5    S5   S4   S3   S3   S3   S3   S3   S3  ...  S3  S3  S3  S3
# 4      S5    S5    S5   S5   S5   S5   S5   S5   S5   S5  ...  S3  S3  S3  S3
# ..    ...   ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ..  ..  ..  ..
# 656    S8    S8    S8   S8   S8   S8   S8   S8   S8   S8  ...  S8  S8  S8  S8
# 657    S8    S8    S8   S8   S8   S8   S8   S8   S8   S8  ...  S8  S8  S8  S8
# 658    S8    S8    S8   S8   S8   S8   S8   S8   S8   S8  ...  S8  S8  S8  S8
# 659    S8    S8    S8   S8   S8   S8   S8   S8   S8   S8  ...  S8  S8  S8  S8
# 660    S8    S8    S8   S8   S8   S8   S8   S8   S8   S8  ...  S8  S8  S8  S8
#
#     M_8 M_9 M_10 M_11 M_12 patient
# 0    S3  S3   S3   S3   S3       2
# 1    S1  S1   S1   S1   S1       1
# 2    S5  S5   S5   S5   S3       1
# 3    S3  S3   S3   S3   S3       1
# 4    S5  S5   S5   S8   S1       1
# ..   ..  ..  ...  ...  ...     ...
# 656  S8  S8   S8   S3   S3       1
# 657  S8  S8   S8   S3   S4       1
# 658  S8  S8   S8   S6   S6       1
# 659  S8  S8   S8   S8   S6       1
# 660  S8  S8   S8   S8   S8      69
#
# [661 rows x 26 columns]

# %%
first_month =  groups.groupby(['M_-12', 'M_-11']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
second_month  =  groups.groupby(['M_-11', 'M_-10']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
third_month  =  groups.groupby(['M_-10', 'M_-9']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
fourth_month  =  groups.groupby(['M_-9', 'M_-8']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
fifth_month  =  groups.groupby(['M_-8', 'M_-7']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
sixth_month  =  groups.groupby(['M_-7', 'M_-6']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
seventh_month  =  groups.groupby(['M_-6', 'M_-5']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
eighth_month  =  groups.groupby(['M_-5', 'M_-4']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
ninth_month  =  groups.groupby(['M_-4', 'M_-3']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
tenth_month  =  groups.groupby(['M_-3', 'M_-2']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
eleventh_month  =  groups.groupby(['M_-2', 'M_-1']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
twelfth_month  =  groups.groupby(['M_-1', 'M_0']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()

thirteenth_month =  groups.groupby(['M_0', 'M_1']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
fourteenth_month  =  groups.groupby(['M_1', 'M_2']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
fifteenth_month  =  groups.groupby(['M_2', 'M_3']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
sixteenth_month  =  groups.groupby(['M_3', 'M_4']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
seventeenth_month  =  groups.groupby(['M_4', 'M_5']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
eighteenth_month  =  groups.groupby(['M_5', 'M_6']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
nineteenth_month  =  groups.groupby(['M_6', 'M_7']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
twentieth_month  =  groups.groupby(['M_7', 'M_8']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
twentyfirst_month  =  groups.groupby(['M_8', 'M_9']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
twentysecond_month  =  groups.groupby(['M_9', 'M_10']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
twentythird_month  =  groups.groupby(['M_10', 'M_11']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()
twentyfourth_month  =  groups.groupby(['M_11', 'M_12']).agg({'patient':'sum'}).rename({'patient':'counts'}).reset_index()

# %%
list_=[first_month,second_month,third_month,fourth_month,fifth_month,sixth_month,seventh_month,eighth_month,ninth_month,tenth_month,eleventh_month,twelfth_month,
       thirteenth_month,fourteenth_month,fifteenth_month,sixteenth_month,seventeenth_month,eighteenth_month,nineteenth_month,twentieth_month,twentyfirst_month,twentysecond_month,
       twentythird_month,twentyfourth_month]
list_
# Out:
# [   M_-12 M_-11  patient
#  0     S3    S3        3
#  1     S4    S5        1
#  2     S5    S5       45
#  3     S5    S6        3
#  4     S5    S8        1
#  5     S6    S5        2
#  6     S6    S6      135
#  7     S6    S8        9
#  8     S7    S5        1
#  9     S7    S6        4
#  10    S7    S7        5
#  11    S7    S8        2
#  12    S8    S5        7
#  13    S8    S6       12
#  14    S8    S7        3
#  15    S8    S8      865,
#     M_-11 M_-10  patient
#  0     S3    S3        3
#  1     S5    S5       53
#  2     S5    S6        1
#  3     S5    S8        2
#  4     S6    S5        1
#  5     S6    S6      145
#  6     S6    S8        8
#  7     S7    S5        1
#  8     S7    S6        1
#  9     S7    S7        5
#  10    S7    S8        1
#  11    S8    S4        2
#  12    S8    S5        6
#  13    S8    S6       13
#  14    S8    S7        5
#  15    S8    S8      851,
#     M_-10 M_-9  patient
#  0     S3   S3        3
#  1     S4   S5        1
#  2     S4   S8        1
#  3     S5   S4        1
#  4     S5   S5       54
#  5     S5   S6        1
#  6     S5   S8        5
#  7     S6   S5        2
#  8     S6   S6      149
#  9     S6   S8        9
#  10    S7   S5        1
#  11    S7   S6        1
#  12    S7   S7        5
#  13    S7   S8        3
#  14    S8   S5        2
#  15    S8   S6        8
#  16    S8   S7        4
#  17    S8   S8      848,
#     M_-9 M_-8  patient
#  0    S3   S3        3
#  1    S4   S3        1
#  2    S5   S4        1
#  3    S5   S5       56
#  4    S5   S6        2
#  5    S5   S8        1
#  6    S6   S6      149
#  7    S6   S7        1
#  8    S6   S8        9
#  9    S7   S5        2
#  10   S7   S7        5
#  11   S7   S8        2
#  12   S8   S5        3
#  13   S8   S6        9
#  14   S8   S7        9
#  15   S8   S8      845,
#     M_-8 M_-7  patient
#  0    S3   S3        4
#  1    S4   S5        1
#  2    S5   S5       58
#  3    S5   S6        2
#  4    S5   S8        1
#  5    S6   S5        2
#  6    S6   S6      147
#  7    S6   S8       11
#  8    S7   S6        3
#  9    S7   S7        9
#  10   S7   S8        3
#  11   S8   S3        1
#  12   S8   S5        2
#  13   S8   S6       13
#  14   S8   S8      841,
#     M_-7 M_-6  patient
#  0    S3   S3        5
#  1    S5   S5       57
#  2    S5   S6        2
#  3    S5   S8        4
#  4    S6   S5        1
#  5    S6   S6      154
#  6    S6   S8       10
#  7    S7   S5        1
#  8    S7   S6        2
#  9    S7   S7        5
#  10   S7   S8        1
#  11   S8   S5        3
#  12   S8   S6        5
#  13   S8   S7        4
#  14   S8   S8      844,
#     M_-6 M_-5  patient
#  0    S3   S3        5
#  1    S5   S5       58
#  2    S5   S6        3
#  3    S5   S7        1
#  4    S6   S3        1
#  5    S6   S4        1
#  6    S6   S5        1
#  7    S6   S6      153
#  8    S6   S7        1
#  9    S6   S8        6
#  10   S7   S7        7
#  11   S7   S8        2
#  12   S8   S4        1
#  13   S8   S5       14
#  14   S8   S6        6
#  15   S8   S7        9
#  16   S8   S8      829,
#     M_-5 M_-4  patient
#  0    S3   S3        6
#  1    S4   S6        1
#  2    S4   S8        1
#  3    S5   S5       67
#  4    S5   S6        2
#  5    S5   S8        4
#  6    S6   S5        3
#  7    S6   S6      149
#  8    S6   S8       10
#  9    S7   S5        2
#  10   S7   S6        1
#  11   S7   S7       10
#  12   S7   S8        5
#  13   S8   S4        1
#  14   S8   S5       15
#  15   S8   S6       11
#  16   S8   S7        3
#  17   S8   S8      807,
#     M_-4 M_-3  patient
#  0    S3   S3        6
#  1    S4   S4        1
#  2    S5   S5       82
#  3    S5   S6        2
#  4    S5   S8        3
#  5    S6   S5        1
#  6    S6   S6      158
#  7    S6   S8        5
#  8    S7   S5        2
#  9    S7   S6        1
#  10   S7   S7        8
#  11   S7   S8        2
#  12   S8   S5        5
#  13   S8   S6       10
#  14   S8   S7        7
#  15   S8   S8      805,
#     M_-3 M_-2  patient
#  0    S3   S3        5
#  1    S3   S6        1
#  2    S4   S4        1
#  3    S5   S5       84
#  4    S5   S6        2
#  5    S5   S7        2
#  6    S5   S8        2
#  7    S6   S6      163
#  8    S6   S8        8
#  9    S7   S7       15
#  10   S8   S5        7
#  11   S8   S6        6
#  12   S8   S7        5
#  13   S8   S8      797,
#     M_-2 M_-1  patient
#  0    S3   S3        4
#  1    S3   S4        1
#  2    S4   S4        1
#  3    S5   S3        1
#  4    S5   S5       83
#  5    S5   S6        1
#  6    S5   S8        6
#  7    S6   S4        1
#  8    S6   S5        1
#  9    S6   S6      162
#  10   S6   S8        8
#  11   S7   S5        2
#  12   S7   S6        1
#  13   S7   S7       17
#  14   S7   S8        2
#  15   S8   S5       10
#  16   S8   S6       16
#  17   S8   S7        9
#  18   S8   S8      772,
#     M_-1 M_0  patient
#  0    S3  S3        5
#  1    S4  S3        1
#  2    S4  S4        2
#  3    S5  S4        1
#  4    S5  S5       89
#  5    S5  S6        1
#  6    S5  S7        2
#  7    S5  S8        3
#  8    S6  S3        1
#  9    S6  S4        1
#  10   S6  S5        5
#  11   S6  S6      170
#  12   S6  S8        3
#  13   S7  S5        3
#  14   S7  S7       18
#  15   S7  S8        5
#  16   S8  S4        6
#  17   S8  S5       28
#  18   S8  S6       28
#  19   S8  S7       42
#  20   S8  S8      684,
#     M_0 M_1  patient
#  0   S3  S3        6
#  1   S3  S6        1
#  2   S4  S3        2
#  3   S4  S4        6
#  4   S4  S5        1
#  5   S4  S8        1
#  6   S5  S3        1
#  7   S5  S5      117
#  8   S5  S6        2
#  9   S5  S8        5
#  10  S6  S3        7
#  11  S6  S4        2
#  12  S6  S5       15
#  13  S6  S6      153
#  14  S6  S7        6
#  15  S6  S8       16
#  16  S7  S5        6
#  17  S7  S6        5
#  18  S7  S7       33
#  19  S7  S8       18
#  20  S8  S2        3
#  21  S8  S3        3
#  22  S8  S4       13
#  23  S8  S5      110
#  24  S8  S6       56
#  25  S8  S7       89
#  26  S8  S8      421,
#     M_1 M_2  patient
#  0   S2  S2        2
#  1   S2  S7        1
#  2   S3  S3       18
#  3   S3  S4        1
#  4   S4  S1        1
#  5   S4  S4       18
#  6   S4  S6        1
#  7   S4  S8        1
#  8   S5  S3        1
#  9   S5  S5      232
#  10  S5  S6        4
#  11  S5  S7        4
#  12  S5  S8        8
#  13  S6  S1        3
#  14  S6  S3        1
#  15  S6  S4        7
#  16  S6  S5       11
#  17  S6  S6      179
#  18  S6  S7        5
#  19  S6  S8       11
#  20  S7  S1        1
#  21  S7  S3        1
#  22  S7  S4        2
#  23  S7  S5       11
#  24  S7  S6       13
#  25  S7  S7       90
#  26  S7  S8       10
#  27  S8  S1        2
#  28  S8  S3        1
#  29  S8  S4        2
#  30  S8  S5       79
#  31  S8  S6       31
#  32  S8  S7      106
#  33  S8  S8      240,
#     M_2 M_3  patient
#  0   S1  S1        7
#  1   S2  S2        1
#  2   S2  S7        1
#  3   S3  S3       21
#  4   S3  S4        1
#  5   S4  S4       30
#  6   S5  S1        2
#  7   S5  S5      321
#  8   S5  S6        2
#  9   S5  S7        4
#  10  S5  S8        4
#  11  S6  S4        3
#  12  S6  S5        5
#  13  S6  S6      203
#  14  S6  S7        4
#  15  S6  S8       13
#  16  S7  S4        1
#  17  S7  S5       13
#  18  S7  S6       13
#  19  S7  S7      168
#  20  S7  S8       11
#  21  S8  S1        1
#  22  S8  S4        2
#  23  S8  S5       25
#  24  S8  S6       13
#  25  S8  S7       31
#  26  S8  S8      198,
#     M_3 M_4  patient
#  0   S1  S1       10
#  1   S2  S2        1
#  2   S3  S3       18
#  3   S3  S5        1
#  4   S3  S7        2
#  5   S4  S3        1
#  6   S4  S4       31
#  7   S4  S5        1
#  8   S4  S6        2
#  9   S4  S8        2
#  10  S5  S1        1
#  11  S5  S4        1
#  12  S5  S5      349
#  13  S5  S6        4
#  14  S5  S7        3
#  15  S5  S8        6
#  16  S6  S3        2
#  17  S6  S4        1
#  18  S6  S5        5
#  19  S6  S6      208
#  20  S6  S7        7
#  21  S6  S8        8
#  22  S7  S1        1
#  23  S7  S4        2
#  24  S7  S5       16
#  25  S7  S6       14
#  26  S7  S7      163
#  27  S7  S8       12
#  28  S8  S1        5
#  29  S8  S4        1
#  30  S8  S5       11
#  31  S8  S6       12
#  32  S8  S7        3
#  33  S8  S8      194,
#     M_4 M_5  patient
#  0   S1  S1       17
#  1   S2  S8        1
#  2   S3  S3       20
#  3   S3  S4        1
#  4   S4  S3        1
#  5   S4  S4       31
#  6   S4  S5        1
#  7   S4  S6        2
#  8   S4  S8        1
#  9   S5  S4        2
#  10  S5  S5      361
#  11  S5  S6        4
#  12  S5  S7        5
#  13  S5  S8       11
#  14  S6  S1        1
#  15  S6  S3        1
#  16  S6  S4        1
#  17  S6  S5        5
#  18  S6  S6      216
#  19  S6  S7        4
#  20  S6  S8       12
#  21  S7  S5        4
#  22  S7  S6       14
#  23  S7  S7      146
#  24  S7  S8       14
#  25  S8  S1        6
#  26  S8  S4        1
#  27  S8  S5        4
#  28  S8  S6       10
#  29  S8  S7       12
#  30  S8  S8      189,
#     M_5 M_6  patient
#  0   S1  S1       24
#  1   S3  S3       21
#  2   S3  S4        1
#  3   S4  S3        1
#  4   S4  S4       27
#  5   S4  S5        4
#  6   S4  S6        1
#  7   S4  S7        2
#  8   S4  S8        1
#  9   S5  S3        1
#  10  S5  S5      351
#  11  S5  S6        7
#  12  S5  S7        3
#  13  S5  S8       13
#  14  S6  S1        1
#  15  S6  S4        2
#  16  S6  S5        3
#  17  S6  S6      224
#  18  S6  S7        3
#  19  S6  S8       13
#  20  S7  S5        9
#  21  S7  S6       15
#  22  S7  S7      123
#  23  S7  S8       20
#  24  S8  S1        4
#  25  S8  S5        6
#  26  S8  S6       10
#  27  S8  S7        5
#  28  S8  S8      203,
#     M_6 M_7  patient
#  0   S1  S1       29
#  1   S3  S3       19
#  2   S3  S4        2
#  3   S3  S5        1
#  4   S3  S7        1
#  5   S4  S4       25
#  6   S4  S5        1
#  7   S4  S6        3
#  8   S4  S8        1
#  9   S5  S1        1
#  10  S5  S4        1
#  11  S5  S5      342
#  12  S5  S6       11
#  13  S5  S7        7
#  14  S5  S8       11
#  15  S6  S1        1
#  16  S6  S2        1
#  17  S6  S4        2
#  18  S6  S5        8
#  19  S6  S6      232
#  20  S6  S7        2
#  21  S6  S8       11
#  22  S7  S2        1
#  23  S7  S4        1
#  24  S7  S5        3
#  25  S7  S6       17
#  26  S7  S7       88
#  27  S7  S8       26
#  28  S8  S1        6
#  29  S8  S5        7
#  30  S8  S6       14
#  31  S8  S7        9
#  32  S8  S8      214,
#     M_7 M_8  patient
#  0   S1  S1       37
#  1   S2  S2        2
#  2   S3  S3       17
#  3   S3  S5        1
#  4   S3  S8        1
#  5   S4  S4       30
#  6   S4  S6        1
#  7   S5  S5      338
#  8   S5  S6       13
#  9   S5  S7        2
#  10  S5  S8        9
#  11  S6  S1        1
#  12  S6  S4        1
#  13  S6  S5        5
#  14  S6  S6      257
#  15  S6  S7        3
#  16  S6  S8       10
#  17  S7  S3        1
#  18  S7  S4        1
#  19  S7  S5       10
#  20  S7  S6       22
#  21  S7  S7       56
#  22  S7  S8       17
#  23  S8  S1        3
#  24  S8  S4        1
#  25  S8  S5        2
#  26  S8  S6       20
#  27  S8  S7       15
#  28  S8  S8      222,
#     M_8 M_9  patient
#  0   S1  S1       41
#  1   S2  S2        1
#  2   S2  S8        1
#  3   S3  S3       16
#  4   S3  S5        1
#  5   S3  S8        1
#  6   S4  S4       32
#  7   S4  S6        1
#  8   S5  S4        2
#  9   S5  S5      340
#  10  S5  S6        7
#  11  S5  S7        1
#  12  S5  S8        6
#  13  S6  S4        1
#  14  S6  S5        6
#  15  S6  S6      285
#  16  S6  S7        4
#  17  S6  S8       17
#  18  S7  S3        1
#  19  S7  S5        1
#  20  S7  S6       19
#  21  S7  S7       42
#  22  S7  S8       13
#  23  S8  S1        5
#  24  S8  S5        9
#  25  S8  S6        8
#  26  S8  S7        8
#  27  S8  S8      229,
#     M_9 M_10  patient
#  0   S1   S1       46
#  1   S2   S2        1
#  2   S3   S3       17
#  3   S4   S3        1
#  4   S4   S4       32
#  5   S4   S7        1
#  6   S4   S8        1
#  7   S5   S3        2
#  8   S5   S5      343
#  9   S5   S6        6
#  10  S5   S7        4
#  11  S5   S8        2
#  12  S6   S1        1
#  13  S6   S3        2
#  14  S6   S5        5
#  15  S6   S6      299
#  16  S6   S7        2
#  17  S6   S8       11
#  18  S7   S3        1
#  19  S7   S4        1
#  20  S7   S5        4
#  21  S7   S6        9
#  22  S7   S7       28
#  23  S7   S8       12
#  24  S8   S1        3
#  25  S8   S5        6
#  26  S8   S6        7
#  27  S8   S7        9
#  28  S8   S8      242,
#     M_10 M_11  patient
#  0    S1   S1       50
#  1    S2   S2        1
#  2    S3   S2        1
#  3    S3   S3       20
#  4    S3   S7        1
#  5    S3   S8        1
#  6    S4   S3        1
#  7    S4   S4       29
#  8    S4   S5        2
#  9    S4   S6        1
#  10   S5   S4        2
#  11   S5   S5      340
#  12   S5   S6        6
#  13   S5   S7        1
#  14   S5   S8        9
#  15   S6   S3        1
#  16   S6   S4        1
#  17   S6   S5        1
#  18   S6   S6      302
#  19   S6   S7        2
#  20   S6   S8       14
#  21   S7   S5        2
#  22   S7   S6        5
#  23   S7   S7       29
#  24   S7   S8        8
#  25   S8   S1        2
#  26   S8   S3        2
#  27   S8   S4        2
#  28   S8   S5        3
#  29   S8   S6       14
#  30   S8   S7        2
#  31   S8   S8      243,
#     M_11 M_12  patient
#  0    S1   S1       52
#  1    S2   S2        1
#  2    S2   S3        1
#  3    S3   S3       20
#  4    S3   S4        1
#  5    S3   S5        1
#  6    S3   S6        1
#  7    S3   S7        1
#  8    S4   S3        3
#  9    S4   S4       29
#  10   S4   S6        2
#  11   S5   S3        1
#  12   S5   S5      332
#  13   S5   S6        7
#  14   S5   S7        1
#  15   S5   S8        7
#  16   S6   S5        8
#  17   S6   S6      298
#  18   S6   S7        1
#  19   S6   S8       21
#  20   S7   S1        1
#  21   S7   S5        5
#  22   S7   S6        3
#  23   S7   S7       20
#  24   S7   S8        6
#  25   S8   S1        4
#  26   S8   S5        3
#  27   S8   S6       13
#  28   S8   S7        4
#  29   S8   S8      251]

# %%
names = []
count_dict = {} #will contain all info of value list
source_list = [] #will contain all info of source
target_list = [] #will contain all info of target

# %%
for i in range(0, len(list_)):
    cols = list_[i].columns
    for x,y,z in zip(list_[i][cols[0]], list_[i][cols[1]], list_[i][cols[2]]):

        if(x+'_M'+str(i+1) not in names):
            names.append(x+'_M'+str(i+1))
        
        count_dict[x+'_M'+str(i+1), y+'_M'+str(i+2)] = z
        source_list.append(x+'_M'+str(i+1))
        target_list.append(y+'_M'+str(i+2))

# %%
source_list
target_list
names
count_dict
# Out:
# {('S3_M1', 'S3_M2'): 3,
#  ('S4_M1', 'S5_M2'): 1,
#  ('S5_M1', 'S5_M2'): 45,
#  ('S5_M1', 'S6_M2'): 3,
#  ('S5_M1', 'S8_M2'): 1,
#  ('S6_M1', 'S5_M2'): 2,
#  ('S6_M1', 'S6_M2'): 135,
#  ('S6_M1', 'S8_M2'): 9,
#  ('S7_M1', 'S5_M2'): 1,
#  ('S7_M1', 'S6_M2'): 4,
#  ('S7_M1', 'S7_M2'): 5,
#  ('S7_M1', 'S8_M2'): 2,
#  ('S8_M1', 'S5_M2'): 7,
#  ('S8_M1', 'S6_M2'): 12,
#  ('S8_M1', 'S7_M2'): 3,
#  ('S8_M1', 'S8_M2'): 865,
#  ('S3_M2', 'S3_M3'): 3,
#  ('S5_M2', 'S5_M3'): 53,
#  ('S5_M2', 'S6_M3'): 1,
#  ('S5_M2', 'S8_M3'): 2,
#  ('S6_M2', 'S5_M3'): 1,
#  ('S6_M2', 'S6_M3'): 145,
#  ('S6_M2', 'S8_M3'): 8,
#  ('S7_M2', 'S5_M3'): 1,
#  ('S7_M2', 'S6_M3'): 1,
#  ('S7_M2', 'S7_M3'): 5,
#  ('S7_M2', 'S8_M3'): 1,
#  ('S8_M2', 'S4_M3'): 2,
#  ('S8_M2', 'S5_M3'): 6,
#  ('S8_M2', 'S6_M3'): 13,
#  ('S8_M2', 'S7_M3'): 5,
#  ('S8_M2', 'S8_M3'): 851,
#  ('S3_M3', 'S3_M4'): 3,
#  ('S4_M3', 'S5_M4'): 1,
#  ('S4_M3', 'S8_M4'): 1,
#  ('S5_M3', 'S4_M4'): 1,
#  ('S5_M3', 'S5_M4'): 54,
#  ('S5_M3', 'S6_M4'): 1,
#  ('S5_M3', 'S8_M4'): 5,
#  ('S6_M3', 'S5_M4'): 2,
#  ('S6_M3', 'S6_M4'): 149,
#  ('S6_M3', 'S8_M4'): 9,
#  ('S7_M3', 'S5_M4'): 1,
#  ('S7_M3', 'S6_M4'): 1,
#  ('S7_M3', 'S7_M4'): 5,
#  ('S7_M3', 'S8_M4'): 3,
#  ('S8_M3', 'S5_M4'): 2,
#  ('S8_M3', 'S6_M4'): 8,
#  ('S8_M3', 'S7_M4'): 4,
#  ('S8_M3', 'S8_M4'): 848,
#  ('S3_M4', 'S3_M5'): 3,
#  ('S4_M4', 'S3_M5'): 1,
#  ('S5_M4', 'S4_M5'): 1,
#  ('S5_M4', 'S5_M5'): 56,
#  ('S5_M4', 'S6_M5'): 2,
#  ('S5_M4', 'S8_M5'): 1,
#  ('S6_M4', 'S6_M5'): 149,
#  ('S6_M4', 'S7_M5'): 1,
#  ('S6_M4', 'S8_M5'): 9,
#  ('S7_M4', 'S5_M5'): 2,
#  ('S7_M4', 'S7_M5'): 5,
#  ('S7_M4', 'S8_M5'): 2,
#  ('S8_M4', 'S5_M5'): 3,
#  ('S8_M4', 'S6_M5'): 9,
#  ('S8_M4', 'S7_M5'): 9,
#  ('S8_M4', 'S8_M5'): 845,
#  ('S3_M5', 'S3_M6'): 4,
#  ('S4_M5', 'S5_M6'): 1,
#  ('S5_M5', 'S5_M6'): 58,
#  ('S5_M5', 'S6_M6'): 2,
#  ('S5_M5', 'S8_M6'): 1,
#  ('S6_M5', 'S5_M6'): 2,
#  ('S6_M5', 'S6_M6'): 147,
#  ('S6_M5', 'S8_M6'): 11,
#  ('S7_M5', 'S6_M6'): 3,
#  ('S7_M5', 'S7_M6'): 9,
#  ('S7_M5', 'S8_M6'): 3,
#  ('S8_M5', 'S3_M6'): 1,
#  ('S8_M5', 'S5_M6'): 2,
#  ('S8_M5', 'S6_M6'): 13,
#  ('S8_M5', 'S8_M6'): 841,
#  ('S3_M6', 'S3_M7'): 5,
#  ('S5_M6', 'S5_M7'): 57,
#  ('S5_M6', 'S6_M7'): 2,
#  ('S5_M6', 'S8_M7'): 4,
#  ('S6_M6', 'S5_M7'): 1,
#  ('S6_M6', 'S6_M7'): 154,
#  ('S6_M6', 'S8_M7'): 10,
#  ('S7_M6', 'S5_M7'): 1,
#  ('S7_M6', 'S6_M7'): 2,
#  ('S7_M6', 'S7_M7'): 5,
#  ('S7_M6', 'S8_M7'): 1,
#  ('S8_M6', 'S5_M7'): 3,
#  ('S8_M6', 'S6_M7'): 5,
#  ('S8_M6', 'S7_M7'): 4,
#  ('S8_M6', 'S8_M7'): 844,
#  ('S3_M7', 'S3_M8'): 5,
#  ('S5_M7', 'S5_M8'): 58,
#  ('S5_M7', 'S6_M8'): 3,
#  ('S5_M7', 'S7_M8'): 1,
#  ('S6_M7', 'S3_M8'): 1,
#  ('S6_M7', 'S4_M8'): 1,
#  ('S6_M7', 'S5_M8'): 1,
#  ('S6_M7', 'S6_M8'): 153,
#  ('S6_M7', 'S7_M8'): 1,
#  ('S6_M7', 'S8_M8'): 6,
#  ('S7_M7', 'S7_M8'): 7,
#  ('S7_M7', 'S8_M8'): 2,
#  ('S8_M7', 'S4_M8'): 1,
#  ('S8_M7', 'S5_M8'): 14,
#  ('S8_M7', 'S6_M8'): 6,
#  ('S8_M7', 'S7_M8'): 9,
#  ('S8_M7', 'S8_M8'): 829,
#  ('S3_M8', 'S3_M9'): 6,
#  ('S4_M8', 'S6_M9'): 1,
#  ('S4_M8', 'S8_M9'): 1,
#  ('S5_M8', 'S5_M9'): 67,
#  ('S5_M8', 'S6_M9'): 2,
#  ('S5_M8', 'S8_M9'): 4,
#  ('S6_M8', 'S5_M9'): 3,
#  ('S6_M8', 'S6_M9'): 149,
#  ('S6_M8', 'S8_M9'): 10,
#  ('S7_M8', 'S5_M9'): 2,
#  ('S7_M8', 'S6_M9'): 1,
#  ('S7_M8', 'S7_M9'): 10,
#  ('S7_M8', 'S8_M9'): 5,
#  ('S8_M8', 'S4_M9'): 1,
#  ('S8_M8', 'S5_M9'): 15,
#  ('S8_M8', 'S6_M9'): 11,
#  ('S8_M8', 'S7_M9'): 3,
#  ('S8_M8', 'S8_M9'): 807,
#  ('S3_M9', 'S3_M10'): 6,
#  ('S4_M9', 'S4_M10'): 1,
#  ('S5_M9', 'S5_M10'): 82,
#  ('S5_M9', 'S6_M10'): 2,
#  ('S5_M9', 'S8_M10'): 3,
#  ('S6_M9', 'S5_M10'): 1,
#  ('S6_M9', 'S6_M10'): 158,
#  ('S6_M9', 'S8_M10'): 5,
#  ('S7_M9', 'S5_M10'): 2,
#  ('S7_M9', 'S6_M10'): 1,
#  ('S7_M9', 'S7_M10'): 8,
#  ('S7_M9', 'S8_M10'): 2,
#  ('S8_M9', 'S5_M10'): 5,
#  ('S8_M9', 'S6_M10'): 10,
#  ('S8_M9', 'S7_M10'): 7,
#  ('S8_M9', 'S8_M10'): 805,
#  ('S3_M10', 'S3_M11'): 5,
#  ('S3_M10', 'S6_M11'): 1,
#  ('S4_M10', 'S4_M11'): 1,
#  ('S5_M10', 'S5_M11'): 84,
#  ('S5_M10', 'S6_M11'): 2,
#  ('S5_M10', 'S7_M11'): 2,
#  ('S5_M10', 'S8_M11'): 2,
#  ('S6_M10', 'S6_M11'): 163,
#  ('S6_M10', 'S8_M11'): 8,
#  ('S7_M10', 'S7_M11'): 15,
#  ('S8_M10', 'S5_M11'): 7,
#  ('S8_M10', 'S6_M11'): 6,
#  ('S8_M10', 'S7_M11'): 5,
#  ('S8_M10', 'S8_M11'): 797,
#  ('S3_M11', 'S3_M12'): 4,
#  ('S3_M11', 'S4_M12'): 1,
#  ('S4_M11', 'S4_M12'): 1,
#  ('S5_M11', 'S3_M12'): 1,
#  ('S5_M11', 'S5_M12'): 83,
#  ('S5_M11', 'S6_M12'): 1,
#  ('S5_M11', 'S8_M12'): 6,
#  ('S6_M11', 'S4_M12'): 1,
#  ('S6_M11', 'S5_M12'): 1,
#  ('S6_M11', 'S6_M12'): 162,
#  ('S6_M11', 'S8_M12'): 8,
#  ('S7_M11', 'S5_M12'): 2,
#  ('S7_M11', 'S6_M12'): 1,
#  ('S7_M11', 'S7_M12'): 17,
#  ('S7_M11', 'S8_M12'): 2,
#  ('S8_M11', 'S5_M12'): 10,
#  ('S8_M11', 'S6_M12'): 16,
#  ('S8_M11', 'S7_M12'): 9,
#  ('S8_M11', 'S8_M12'): 772,
#  ('S3_M12', 'S3_M13'): 5,
#  ('S4_M12', 'S3_M13'): 1,
#  ('S4_M12', 'S4_M13'): 2,
#  ('S5_M12', 'S4_M13'): 1,
#  ('S5_M12', 'S5_M13'): 89,
#  ('S5_M12', 'S6_M13'): 1,
#  ('S5_M12', 'S7_M13'): 2,
#  ('S5_M12', 'S8_M13'): 3,
#  ('S6_M12', 'S3_M13'): 1,
#  ('S6_M12', 'S4_M13'): 1,
#  ('S6_M12', 'S5_M13'): 5,
#  ('S6_M12', 'S6_M13'): 170,
#  ('S6_M12', 'S8_M13'): 3,
#  ('S7_M12', 'S5_M13'): 3,
#  ('S7_M12', 'S7_M13'): 18,
#  ('S7_M12', 'S8_M13'): 5,
#  ('S8_M12', 'S4_M13'): 6,
#  ('S8_M12', 'S5_M13'): 28,
#  ('S8_M12', 'S6_M13'): 28,
#  ('S8_M12', 'S7_M13'): 42,
#  ('S8_M12', 'S8_M13'): 684,
#  ('S3_M13', 'S3_M14'): 6,
#  ('S3_M13', 'S6_M14'): 1,
#  ('S4_M13', 'S3_M14'): 2,
#  ('S4_M13', 'S4_M14'): 6,
#  ('S4_M13', 'S5_M14'): 1,
#  ('S4_M13', 'S8_M14'): 1,
#  ('S5_M13', 'S3_M14'): 1,
#  ('S5_M13', 'S5_M14'): 117,
#  ('S5_M13', 'S6_M14'): 2,
#  ('S5_M13', 'S8_M14'): 5,
#  ('S6_M13', 'S3_M14'): 7,
#  ('S6_M13', 'S4_M14'): 2,
#  ('S6_M13', 'S5_M14'): 15,
#  ('S6_M13', 'S6_M14'): 153,
#  ('S6_M13', 'S7_M14'): 6,
#  ('S6_M13', 'S8_M14'): 16,
#  ('S7_M13', 'S5_M14'): 6,
#  ('S7_M13', 'S6_M14'): 5,
#  ('S7_M13', 'S7_M14'): 33,
#  ('S7_M13', 'S8_M14'): 18,
#  ('S8_M13', 'S2_M14'): 3,
#  ('S8_M13', 'S3_M14'): 3,
#  ('S8_M13', 'S4_M14'): 13,
#  ('S8_M13', 'S5_M14'): 110,
#  ('S8_M13', 'S6_M14'): 56,
#  ('S8_M13', 'S7_M14'): 89,
#  ('S8_M13', 'S8_M14'): 421,
#  ('S2_M14', 'S2_M15'): 2,
#  ('S2_M14', 'S7_M15'): 1,
#  ('S3_M14', 'S3_M15'): 18,
#  ('S3_M14', 'S4_M15'): 1,
#  ('S4_M14', 'S1_M15'): 1,
#  ('S4_M14', 'S4_M15'): 18,
#  ('S4_M14', 'S6_M15'): 1,
#  ('S4_M14', 'S8_M15'): 1,
#  ('S5_M14', 'S3_M15'): 1,
#  ('S5_M14', 'S5_M15'): 232,
#  ('S5_M14', 'S6_M15'): 4,
#  ('S5_M14', 'S7_M15'): 4,
#  ('S5_M14', 'S8_M15'): 8,
#  ('S6_M14', 'S1_M15'): 3,
#  ('S6_M14', 'S3_M15'): 1,
#  ('S6_M14', 'S4_M15'): 7,
#  ('S6_M14', 'S5_M15'): 11,
#  ('S6_M14', 'S6_M15'): 179,
#  ('S6_M14', 'S7_M15'): 5,
#  ('S6_M14', 'S8_M15'): 11,
#  ('S7_M14', 'S1_M15'): 1,
#  ('S7_M14', 'S3_M15'): 1,
#  ('S7_M14', 'S4_M15'): 2,
#  ('S7_M14', 'S5_M15'): 11,
#  ('S7_M14', 'S6_M15'): 13,
#  ('S7_M14', 'S7_M15'): 90,
#  ('S7_M14', 'S8_M15'): 10,
#  ('S8_M14', 'S1_M15'): 2,
#  ('S8_M14', 'S3_M15'): 1,
#  ('S8_M14', 'S4_M15'): 2,
#  ('S8_M14', 'S5_M15'): 79,
#  ('S8_M14', 'S6_M15'): 31,
#  ('S8_M14', 'S7_M15'): 106,
#  ('S8_M14', 'S8_M15'): 240,
#  ('S1_M15', 'S1_M16'): 7,
#  ('S2_M15', 'S2_M16'): 1,
#  ('S2_M15', 'S7_M16'): 1,
#  ('S3_M15', 'S3_M16'): 21,
#  ('S3_M15', 'S4_M16'): 1,
#  ('S4_M15', 'S4_M16'): 30,
#  ('S5_M15', 'S1_M16'): 2,
#  ('S5_M15', 'S5_M16'): 321,
#  ('S5_M15', 'S6_M16'): 2,
#  ('S5_M15', 'S7_M16'): 4,
#  ('S5_M15', 'S8_M16'): 4,
#  ('S6_M15', 'S4_M16'): 3,
#  ('S6_M15', 'S5_M16'): 5,
#  ('S6_M15', 'S6_M16'): 203,
#  ('S6_M15', 'S7_M16'): 4,
#  ('S6_M15', 'S8_M16'): 13,
#  ('S7_M15', 'S4_M16'): 1,
#  ('S7_M15', 'S5_M16'): 13,
#  ('S7_M15', 'S6_M16'): 13,
#  ('S7_M15', 'S7_M16'): 168,
#  ('S7_M15', 'S8_M16'): 11,
#  ('S8_M15', 'S1_M16'): 1,
#  ('S8_M15', 'S4_M16'): 2,
#  ('S8_M15', 'S5_M16'): 25,
#  ('S8_M15', 'S6_M16'): 13,
#  ('S8_M15', 'S7_M16'): 31,
#  ('S8_M15', 'S8_M16'): 198,
#  ('S1_M16', 'S1_M17'): 10,
#  ('S2_M16', 'S2_M17'): 1,
#  ('S3_M16', 'S3_M17'): 18,
#  ('S3_M16', 'S5_M17'): 1,
#  ('S3_M16', 'S7_M17'): 2,
#  ('S4_M16', 'S3_M17'): 1,
#  ('S4_M16', 'S4_M17'): 31,
#  ('S4_M16', 'S5_M17'): 1,
#  ('S4_M16', 'S6_M17'): 2,
#  ('S4_M16', 'S8_M17'): 2,
#  ('S5_M16', 'S1_M17'): 1,
#  ('S5_M16', 'S4_M17'): 1,
#  ('S5_M16', 'S5_M17'): 349,
#  ('S5_M16', 'S6_M17'): 4,
#  ('S5_M16', 'S7_M17'): 3,
#  ('S5_M16', 'S8_M17'): 6,
#  ('S6_M16', 'S3_M17'): 2,
#  ('S6_M16', 'S4_M17'): 1,
#  ('S6_M16', 'S5_M17'): 5,
#  ('S6_M16', 'S6_M17'): 208,
#  ('S6_M16', 'S7_M17'): 7,
#  ('S6_M16', 'S8_M17'): 8,
#  ('S7_M16', 'S1_M17'): 1,
#  ('S7_M16', 'S4_M17'): 2,
#  ('S7_M16', 'S5_M17'): 16,
#  ('S7_M16', 'S6_M17'): 14,
#  ('S7_M16', 'S7_M17'): 163,
#  ('S7_M16', 'S8_M17'): 12,
#  ('S8_M16', 'S1_M17'): 5,
#  ('S8_M16', 'S4_M17'): 1,
#  ('S8_M16', 'S5_M17'): 11,
#  ('S8_M16', 'S6_M17'): 12,
#  ('S8_M16', 'S7_M17'): 3,
#  ('S8_M16', 'S8_M17'): 194,
#  ('S1_M17', 'S1_M18'): 17,
#  ('S2_M17', 'S8_M18'): 1,
#  ('S3_M17', 'S3_M18'): 20,
#  ('S3_M17', 'S4_M18'): 1,
#  ('S4_M17', 'S3_M18'): 1,
#  ('S4_M17', 'S4_M18'): 31,
#  ('S4_M17', 'S5_M18'): 1,
#  ('S4_M17', 'S6_M18'): 2,
#  ('S4_M17', 'S8_M18'): 1,
#  ('S5_M17', 'S4_M18'): 2,
#  ('S5_M17', 'S5_M18'): 361,
#  ('S5_M17', 'S6_M18'): 4,
#  ('S5_M17', 'S7_M18'): 5,
#  ('S5_M17', 'S8_M18'): 11,
#  ('S6_M17', 'S1_M18'): 1,
#  ('S6_M17', 'S3_M18'): 1,
#  ('S6_M17', 'S4_M18'): 1,
#  ('S6_M17', 'S5_M18'): 5,
#  ('S6_M17', 'S6_M18'): 216,
#  ('S6_M17', 'S7_M18'): 4,
#  ('S6_M17', 'S8_M18'): 12,
#  ('S7_M17', 'S5_M18'): 4,
#  ('S7_M17', 'S6_M18'): 14,
#  ('S7_M17', 'S7_M18'): 146,
#  ('S7_M17', 'S8_M18'): 14,
#  ('S8_M17', 'S1_M18'): 6,
#  ('S8_M17', 'S4_M18'): 1,
#  ('S8_M17', 'S5_M18'): 4,
#  ('S8_M17', 'S6_M18'): 10,
#  ('S8_M17', 'S7_M18'): 12,
#  ('S8_M17', 'S8_M18'): 189,
#  ('S1_M18', 'S1_M19'): 24,
#  ('S3_M18', 'S3_M19'): 21,
#  ('S3_M18', 'S4_M19'): 1,
#  ('S4_M18', 'S3_M19'): 1,
#  ('S4_M18', 'S4_M19'): 27,
#  ('S4_M18', 'S5_M19'): 4,
#  ('S4_M18', 'S6_M19'): 1,
#  ('S4_M18', 'S7_M19'): 2,
#  ('S4_M18', 'S8_M19'): 1,
#  ('S5_M18', 'S3_M19'): 1,
#  ('S5_M18', 'S5_M19'): 351,
#  ('S5_M18', 'S6_M19'): 7,
#  ('S5_M18', 'S7_M19'): 3,
#  ('S5_M18', 'S8_M19'): 13,
#  ('S6_M18', 'S1_M19'): 1,
#  ('S6_M18', 'S4_M19'): 2,
#  ('S6_M18', 'S5_M19'): 3,
#  ('S6_M18', 'S6_M19'): 224,
#  ('S6_M18', 'S7_M19'): 3,
#  ('S6_M18', 'S8_M19'): 13,
#  ('S7_M18', 'S5_M19'): 9,
#  ('S7_M18', 'S6_M19'): 15,
#  ('S7_M18', 'S7_M19'): 123,
#  ('S7_M18', 'S8_M19'): 20,
#  ('S8_M18', 'S1_M19'): 4,
#  ('S8_M18', 'S5_M19'): 6,
#  ('S8_M18', 'S6_M19'): 10,
#  ('S8_M18', 'S7_M19'): 5,
#  ('S8_M18', 'S8_M19'): 203,
#  ('S1_M19', 'S1_M20'): 29,
#  ('S3_M19', 'S3_M20'): 19,
#  ('S3_M19', 'S4_M20'): 2,
#  ('S3_M19', 'S5_M20'): 1,
#  ('S3_M19', 'S7_M20'): 1,
#  ('S4_M19', 'S4_M20'): 25,
#  ('S4_M19', 'S5_M20'): 1,
#  ('S4_M19', 'S6_M20'): 3,
#  ('S4_M19', 'S8_M20'): 1,
#  ('S5_M19', 'S1_M20'): 1,
#  ('S5_M19', 'S4_M20'): 1,
#  ('S5_M19', 'S5_M20'): 342,
#  ('S5_M19', 'S6_M20'): 11,
#  ('S5_M19', 'S7_M20'): 7,
#  ('S5_M19', 'S8_M20'): 11,
#  ('S6_M19', 'S1_M20'): 1,
#  ('S6_M19', 'S2_M20'): 1,
#  ('S6_M19', 'S4_M20'): 2,
#  ('S6_M19', 'S5_M20'): 8,
#  ('S6_M19', 'S6_M20'): 232,
#  ('S6_M19', 'S7_M20'): 2,
#  ('S6_M19', 'S8_M20'): 11,
#  ('S7_M19', 'S2_M20'): 1,
#  ('S7_M19', 'S4_M20'): 1,
#  ('S7_M19', 'S5_M20'): 3,
#  ('S7_M19', 'S6_M20'): 17,
#  ('S7_M19', 'S7_M20'): 88,
#  ('S7_M19', 'S8_M20'): 26,
#  ('S8_M19', 'S1_M20'): 6,
#  ('S8_M19', 'S5_M20'): 7,
#  ('S8_M19', 'S6_M20'): 14,
#  ('S8_M19', 'S7_M20'): 9,
#  ('S8_M19', 'S8_M20'): 214,
#  ('S1_M20', 'S1_M21'): 37,
#  ('S2_M20', 'S2_M21'): 2,
#  ('S3_M20', 'S3_M21'): 17,
#  ('S3_M20', 'S5_M21'): 1,
#  ('S3_M20', 'S8_M21'): 1,
#  ('S4_M20', 'S4_M21'): 30,
#  ('S4_M20', 'S6_M21'): 1,
#  ('S5_M20', 'S5_M21'): 338,
#  ('S5_M20', 'S6_M21'): 13,
#  ('S5_M20', 'S7_M21'): 2,
#  ('S5_M20', 'S8_M21'): 9,
#  ('S6_M20', 'S1_M21'): 1,
#  ('S6_M20', 'S4_M21'): 1,
#  ('S6_M20', 'S5_M21'): 5,
#  ('S6_M20', 'S6_M21'): 257,
#  ('S6_M20', 'S7_M21'): 3,
#  ('S6_M20', 'S8_M21'): 10,
#  ('S7_M20', 'S3_M21'): 1,
#  ('S7_M20', 'S4_M21'): 1,
#  ('S7_M20', 'S5_M21'): 10,
#  ('S7_M20', 'S6_M21'): 22,
#  ('S7_M20', 'S7_M21'): 56,
#  ('S7_M20', 'S8_M21'): 17,
#  ('S8_M20', 'S1_M21'): 3,
#  ('S8_M20', 'S4_M21'): 1,
#  ('S8_M20', 'S5_M21'): 2,
#  ('S8_M20', 'S6_M21'): 20,
#  ('S8_M20', 'S7_M21'): 15,
#  ('S8_M20', 'S8_M21'): 222,
#  ('S1_M21', 'S1_M22'): 41,
#  ('S2_M21', 'S2_M22'): 1,
#  ('S2_M21', 'S8_M22'): 1,
#  ('S3_M21', 'S3_M22'): 16,
#  ('S3_M21', 'S5_M22'): 1,
#  ('S3_M21', 'S8_M22'): 1,
#  ('S4_M21', 'S4_M22'): 32,
#  ('S4_M21', 'S6_M22'): 1,
#  ('S5_M21', 'S4_M22'): 2,
#  ('S5_M21', 'S5_M22'): 340,
#  ('S5_M21', 'S6_M22'): 7,
#  ('S5_M21', 'S7_M22'): 1,
#  ('S5_M21', 'S8_M22'): 6,
#  ('S6_M21', 'S4_M22'): 1,
#  ('S6_M21', 'S5_M22'): 6,
#  ('S6_M21', 'S6_M22'): 285,
#  ('S6_M21', 'S7_M22'): 4,
#  ('S6_M21', 'S8_M22'): 17,
#  ('S7_M21', 'S3_M22'): 1,
#  ('S7_M21', 'S5_M22'): 1,
#  ('S7_M21', 'S6_M22'): 19,
#  ('S7_M21', 'S7_M22'): 42,
#  ('S7_M21', 'S8_M22'): 13,
#  ('S8_M21', 'S1_M22'): 5,
#  ('S8_M21', 'S5_M22'): 9,
#  ('S8_M21', 'S6_M22'): 8,
#  ('S8_M21', 'S7_M22'): 8,
#  ('S8_M21', 'S8_M22'): 229,
#  ('S1_M22', 'S1_M23'): 46,
#  ('S2_M22', 'S2_M23'): 1,
#  ('S3_M22', 'S3_M23'): 17,
#  ('S4_M22', 'S3_M23'): 1,
#  ('S4_M22', 'S4_M23'): 32,
#  ('S4_M22', 'S7_M23'): 1,
#  ('S4_M22', 'S8_M23'): 1,
#  ('S5_M22', 'S3_M23'): 2,
#  ('S5_M22', 'S5_M23'): 343,
#  ('S5_M22', 'S6_M23'): 6,
#  ('S5_M22', 'S7_M23'): 4,
#  ('S5_M22', 'S8_M23'): 2,
#  ('S6_M22', 'S1_M23'): 1,
#  ('S6_M22', 'S3_M23'): 2,
#  ('S6_M22', 'S5_M23'): 5,
#  ('S6_M22', 'S6_M23'): 299,
#  ('S6_M22', 'S7_M23'): 2,
#  ('S6_M22', 'S8_M23'): 11,
#  ('S7_M22', 'S3_M23'): 1,
#  ('S7_M22', 'S4_M23'): 1,
#  ('S7_M22', 'S5_M23'): 4,
#  ('S7_M22', 'S6_M23'): 9,
#  ('S7_M22', 'S7_M23'): 28,
#  ('S7_M22', 'S8_M23'): 12,
#  ('S8_M22', 'S1_M23'): 3,
#  ('S8_M22', 'S5_M23'): 6,
#  ('S8_M22', 'S6_M23'): 7,
#  ('S8_M22', 'S7_M23'): 9,
#  ('S8_M22', 'S8_M23'): 242,
#  ('S1_M23', 'S1_M24'): 50,
#  ('S2_M23', 'S2_M24'): 1,
#  ('S3_M23', 'S2_M24'): 1,
#  ('S3_M23', 'S3_M24'): 20,
#  ('S3_M23', 'S7_M24'): 1,
#  ('S3_M23', 'S8_M24'): 1,
#  ('S4_M23', 'S3_M24'): 1,
#  ('S4_M23', 'S4_M24'): 29,
#  ('S4_M23', 'S5_M24'): 2,
#  ('S4_M23', 'S6_M24'): 1,
#  ('S5_M23', 'S4_M24'): 2,
#  ('S5_M23', 'S5_M24'): 340,
#  ('S5_M23', 'S6_M24'): 6,
#  ('S5_M23', 'S7_M24'): 1,
#  ('S5_M23', 'S8_M24'): 9,
#  ('S6_M23', 'S3_M24'): 1,
#  ('S6_M23', 'S4_M24'): 1,
#  ('S6_M23', 'S5_M24'): 1,
#  ('S6_M23', 'S6_M24'): 302,
#  ('S6_M23', 'S7_M24'): 2,
#  ('S6_M23', 'S8_M24'): 14,
#  ('S7_M23', 'S5_M24'): 2,
#  ('S7_M23', 'S6_M24'): 5,
#  ('S7_M23', 'S7_M24'): 29,
#  ('S7_M23', 'S8_M24'): 8,
#  ('S8_M23', 'S1_M24'): 2,
#  ('S8_M23', 'S3_M24'): 2,
#  ('S8_M23', 'S4_M24'): 2,
#  ('S8_M23', 'S5_M24'): 3,
#  ('S8_M23', 'S6_M24'): 14,
#  ('S8_M23', 'S7_M24'): 2,
#  ('S8_M23', 'S8_M24'): 243,
#  ('S1_M24', 'S1_M25'): 52,
#  ('S2_M24', 'S2_M25'): 1,
#  ('S2_M24', 'S3_M25'): 1,
#  ('S3_M24', 'S3_M25'): 20,
#  ('S3_M24', 'S4_M25'): 1,
#  ('S3_M24', 'S5_M25'): 1,
#  ('S3_M24', 'S6_M25'): 1,
#  ('S3_M24', 'S7_M25'): 1,
#  ('S4_M24', 'S3_M25'): 3,
#  ('S4_M24', 'S4_M25'): 29,
#  ('S4_M24', 'S6_M25'): 2,
#  ('S5_M24', 'S3_M25'): 1,
#  ('S5_M24', 'S5_M25'): 332,
#  ('S5_M24', 'S6_M25'): 7,
#  ('S5_M24', 'S7_M25'): 1,
#  ('S5_M24', 'S8_M25'): 7,
#  ('S6_M24', 'S5_M25'): 8,
#  ('S6_M24', 'S6_M25'): 298,
#  ('S6_M24', 'S7_M25'): 1,
#  ('S6_M24', 'S8_M25'): 21,
#  ('S7_M24', 'S1_M25'): 1,
#  ('S7_M24', 'S5_M25'): 5,
#  ('S7_M24', 'S6_M25'): 3,
#  ('S7_M24', 'S7_M25'): 20,
#  ('S7_M24', 'S8_M25'): 6,
#  ('S8_M24', 'S1_M25'): 4,
#  ('S8_M24', 'S5_M25'): 3,
#  ('S8_M24', 'S6_M25'): 13,
#  ('S8_M24', 'S7_M25'): 4,
#  ('S8_M24', 'S8_M25'): 251}

# %%
for v in target_list:
    if v not in names:
        names.append(v)

# %%
all_numerics = {}

for i in range(0, len(names)):
    all_numerics[names[i]] = i

# %%
fig = go.Figure(data = [go.Sankey(
    node=dict(thickness=5, color='blue',),
    link=dict(
        source = [all_numerics[x] for x in source_list],
        target = [all_numerics[x] for x in target_list],
        value = [count_dict[x,y] for x,y in zip(source_list,target_list)],
    )
)])

# %%
fig.update_layout(font_size=15, width=1200, height=800, margin=dict(t=30,l=30,b=30,r=30))
fig.show()

# %%
names
# Out:
# ['S3_M1',
#  'S4_M1',
#  'S5_M1',
#  'S6_M1',
#  'S7_M1',
#  'S8_M1',
#  'S3_M2',
#  'S5_M2',
#  'S6_M2',
#  'S7_M2',
#  'S8_M2',
#  'S3_M3',
#  'S4_M3',
#  'S5_M3',
#  'S6_M3',
#  'S7_M3',
#  'S8_M3',
#  'S3_M4',
#  'S4_M4',
#  'S5_M4',
#  'S6_M4',
#  'S7_M4',
#  'S8_M4',
#  'S3_M5',
#  'S4_M5',
#  'S5_M5',
#  'S6_M5',
#  'S7_M5',
#  'S8_M5',
#  'S3_M6',
#  'S5_M6',
#  'S6_M6',
#  'S7_M6',
#  'S8_M6',
#  'S3_M7',
#  'S5_M7',
#  'S6_M7',
#  'S7_M7',
#  'S8_M7',
#  'S3_M8',
#  'S4_M8',
#  'S5_M8',
#  'S6_M8',
#  'S7_M8',
#  'S8_M8',
#  'S3_M9',
#  'S4_M9',
#  'S5_M9',
#  'S6_M9',
#  'S7_M9',
#  'S8_M9',
#  'S3_M10',
#  'S4_M10',
#  'S5_M10',
#  'S6_M10',
#  'S7_M10',
#  'S8_M10',
#  'S3_M11',
#  'S4_M11',
#  'S5_M11',
#  'S6_M11',
#  'S7_M11',
#  'S8_M11',
#  'S3_M12',
#  'S4_M12',
#  'S5_M12',
#  'S6_M12',
#  'S7_M12',
#  'S8_M12',
#  'S3_M13',
#  'S4_M13',
#  'S5_M13',
#  'S6_M13',
#  'S7_M13',
#  'S8_M13',
#  'S2_M14',
#  'S3_M14',
#  'S4_M14',
#  'S5_M14',
#  'S6_M14',
#  'S7_M14',
#  'S8_M14',
#  'S1_M15',
#  'S2_M15',
#  'S3_M15',
#  'S4_M15',
#  'S5_M15',
#  'S6_M15',
#  'S7_M15',
#  'S8_M15',
#  'S1_M16',
#  'S2_M16',
#  'S3_M16',
#  'S4_M16',
#  'S5_M16',
#  'S6_M16',
#  'S7_M16',
#  'S8_M16',
#  'S1_M17',
#  'S2_M17',
#  'S3_M17',
#  'S4_M17',
#  'S5_M17',
#  'S6_M17',
#  'S7_M17',
#  'S8_M17',
#  'S1_M18',
#  'S3_M18',
#  'S4_M18',
#  'S5_M18',
#  'S6_M18',
#  'S7_M18',
#  'S8_M18',
#  'S1_M19',
#  'S3_M19',
#  'S4_M19',
#  'S5_M19',
#  'S6_M19',
#  'S7_M19',
#  'S8_M19',
#  'S1_M20',
#  'S2_M20',
#  'S3_M20',
#  'S4_M20',
#  'S5_M20',
#  'S6_M20',
#  'S7_M20',
#  'S8_M20',
#  'S1_M21',
#  'S2_M21',
#  'S3_M21',
#  'S4_M21',
#  'S5_M21',
#  'S6_M21',
#  'S7_M21',
#  'S8_M21',
#  'S1_M22',
#  'S2_M22',
#  'S3_M22',
#  'S4_M22',
#  'S5_M22',
#  'S6_M22',
#  'S7_M22',
#  'S8_M22',
#  'S1_M23',
#  'S2_M23',
#  'S3_M23',
#  'S4_M23',
#  'S5_M23',
#  'S6_M23',
#  'S7_M23',
#  'S8_M23',
#  'S1_M24',
#  'S2_M24',
#  'S3_M24',
#  'S4_M24',
#  'S5_M24',
#  'S6_M24',
#  'S7_M24',
#  'S8_M24',
#  'S1_M25',
#  'S2_M25',
#  'S3_M25',
#  'S4_M25',
#  'S5_M25',
#  'S6_M25',
#  'S7_M25',
#  'S8_M25']

# %%
color_dict = {
    'S1': 'rgba(255, 87, 34, 0.7)',   # Orange
    'S2': 'rgba(0, 0, 0, 0.7)',   # Black
    'S3': 'rgba(156, 39, 176, 0.7)',   # Purple
    'S4': 'rgba(76, 175, 80, 0.7)',   # Green
    'S5': 'rgba(255, 193, 7, 0.7)',   # Amber
    'S6': 'rgba(33, 150, 243, 0.7)',   # Indigo
    'S7': 'rgba(233, 30, 99, 0.7)',   # Pink
    'S8': 'rgba(255, 152, 0, 0.7)'   # Deep Orange
}


color_dict_link = {
    'S1': 'rgba(255, 87, 34, 0.3)',   # Orange
    'S2': 'rgba(0, 0, 0, 0.7)',   # Black
    'S3': 'rgba(156, 39, 176, 0.3)',   # Purple
    'S4': 'rgba(76, 175, 80, 0.3)',   # Green
    'S5': 'rgba(255, 193, 7, 0.3)',   # Amber
    'S6': 'rgba(33, 150, 243, 0.3)',   # Indigo
    'S7': 'rgba(233, 30, 99, 0.3)',   # Pink
    'S8': 'rgba(255, 152, 0, 0.3)'   # Deep Orange
}

# %%
color_dict = {
    'S1': 'rgba(244, 238, 225, 0.8)',   # Light Beige
    'S2': 'rgba(244, 238, 225, 0.8)',   # Light Beige
    'S3': 'rgba(255, 105, 180, 0.8)',   # Strong Pink Redish  # Evero
    'S4': 'rgba(65, 105, 225, 0.8)',   # Strong Attractive Blue # CDK
    'S5': 'rgba(255, 0, 0, 0.8)',  # Strong Red Other target
    'S6': 'rgba(173, 216, 230, 0.8)',   # lightblue Hormonal
    'S7': 'rgba(255, 165, 0, 0.4)',  # yellow # other Chemo
    'S8': 'rgba(192, 192, 192, 0.8)'   # Lighter Gray
}

color_dict_link = {
    'S1': 'rgba(244, 238, 225, 0.4)',   # Light Beige
    'S2': 'rgba(244, 238, 225, 0.4)',   # Light Beige
    'S3': 'rgba(255, 105, 180, 0.4)',   # Strong Pink Redish
    'S4': 'rgba(65, 105, 225, 0.4)',   # Strong Attractive Blue
    'S5': 'rgba(255, 0, 0, 0.5)',  # Strong Red Other target
    'S6': 'rgba(173, 216, 230, 0.4)',   # lightblue Hormonal
    'S7': 'rgba(255, 165, 0, 0.3)',  # yellow # other Chemo
    'S8': 'rgba(192, 192, 192, 0.4)'   # Lighter Gray
}

# %%
fig = go.Figure(data = [go.Sankey(
    node=dict(
        thickness=10,
         line = dict(color = None, width = 0.01),
         color= [color_dict[x.split('_')[0]] for x in names],),
    link=dict(
        source = [all_numerics[x] for x in source_list],
        target = [all_numerics[x] for x in target_list],
        value = [count_dict[x,y] for x,y in zip(source_list,target_list)],
        color= [color_dict_link[x.split('_')[0]] for x in target_list]
    )
)])

# %%
fig.update_layout(font_size=15, width=1200, height=800, margin=dict(t=30,l=30,b=30,r=30))
